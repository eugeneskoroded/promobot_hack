# %%
from transformers import pipeline
import pandas as pd
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
# classifier = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli", device=0)

# %%
synonyms = {
    'Здравоохранение/Медицина': ['лечение', 'медицинские услуги', 'здравотдел', 'здравпункт', 'мед. обслуживание', 'мин. здрав'],
    'Социальное обслуживание и защита': ['соцобслуживание', 'социальная защита', 'благотворительность', "льготы и пособие", 'социальная поддержка', 'социальная помощь'],
    'Дороги': ['автодороги', 'шоссе', 'трассы', 'проезжая часть', 'дорожная сеть'],
    'ЖКХ': ['коммунальные услуги', 'жилищное хозяйство', 'коммуналка', 'ЖКУ', 'жилищно-коммунальные работы'],
    'Благоустройство': ['озеленение', 'ландшафтный дизайн', 'уличная обстановка', 'уборка территории', 'улучшение территории'],
    'Мусор/Свалки/ТКО': ['отходы', 'утилизация мусора', 'захоронение отходов', 'переработка мусора', 'уборка отходов'],
    'Общественный транспорт': ['пассажирские перевозки', 'общественный транспорт', 'городской транспорт', 'муниципальный транспорт', 'автобусы и троллейбусы', 'оставновки и транспорт'],
    'Коронавирус': ['COVID-19', 'пандемия', 'вирусная инфекция', 'корона', 'эпидемия коронавируса'],
    'Образование': ['педагогика', 'учебный процесс', 'школьное обучение', 'образовательные услуги', 'учебные заведения'],
    'Безопасность': ['охрана порядка', 'профилактика преступлений', 'защита', 'безопасное пространство', 'недопущение нарушений'],
    'Связь и телевидение': ['телекоммуникации', 'масс-медиа', 'информационные сервисы', 'радиовещание', 'информационная индустрия'],
    'Мобилизация': ['призыв', 'военный набор', 'резервисты', 'подготовка к обороне', 'мобилизационная подготовка', 'СВО', 'военная операция'],
    'Физическая культура и спорт': ['спортивная деятельность', 'физкультура', 'спортивные мероприятия', 'физическое воспитание', 'спорт'],
    'Строительство и архитектура': ['застройка', 'архитектурное планирование', 'стройиндустрия', 'градостроительство', 'строительные работы'],
    'Газ и топливо': ['газоснабжение', 'топливная индустрия', 'нефтегаз', 'энергоресурсы', 'газовая промышленность'],
    'Спецпроекты': ['особые программы', 'специальные инициативы', 'эксклюзивные проекты', 'инновационные проекты', 'спецработы'],
    'Культура': ['искусство', 'духовное наследие', 'культурное развитие', 'творчество', 'культурная жизнь'],
    'Электроснабжение': ['энергоснабжение', 'электроэнергия', 'подача тока', 'электросеть', 'энергетика'],
    'Экономика и бизнес': ['экономическая деятельность', 'бизнес-сектор', 'финансы и торговля', 'предпринимательство', 'торгово-экономический комплекс'],
    'Экология': ['охрана окружающей среды', 'природопользование', 'экосистема', 'природозащита', 'экологическая безопасность'],
    'Роспотребнадзор': ['защита прав потребителей', 'санитарный надзор', 'надзор за услугами', 'государственный контроль', 'контроль качества'],
    'Памятники и объекты культурного наследия': ['исторические объекты', 'культурные ценности', 'заповедники', 'архитектурное наследие', 'музей под открытым небом'],
    'Государственная собственность': ['госимущество', 'государственные активы', 'федеральная собственность', 'муниципальное имущество', 'державные резервы'],
    'Торговля': ['коммерция', 'продажи', 'рыночная деятельность', 'внешняя и внутренняя торговля', 'торговый бизнес'],
    'МФЦ "Мои документы"': ['центры обслуживания', 'госуслуги', 'административные сервисы', 'общественные сервисы', 'документационное обслуживание'],
    # 'Погребение и похоронное дело' - для этого термина трудно подобрать синонимы, которые точно передавали бы суть деятельности без контекстной потери.
    'Погребение и похоронное дело': ['ритуальные услуги', 'похоронная служба', 'захоронение', 'ритуальная служба', 'похороны']
}

# %%
def get_dicts(results):
    dicts_ = []
    for result in results:
        label_score_pairs = list(zip(result['labels'], result['scores']))
        
        # Use a dictionary comprehension to convert pairs into a dictionary
        label_score_dict = {label: score for label, score in label_score_pairs}
        dicts_.append(label_score_dict)
    return dicts_

# %%
def predict_zero_shot(text, label_texts, model, tokenizer, label='entailment', normalize=True):
    label_texts
    tokens = tokenizer([text] * len(label_texts), label_texts, truncation=True, return_tensors='pt', padding=True)
    with torch.inference_mode():
        result = torch.softmax(model(**tokens.to(model.device)).logits, -1)
    proba = result[:, model.config.label2id[label]].cpu().numpy()
    if normalize:
        proba /= sum(proba)
    return proba

# %%
data = pd.read_csv("data/train.csv")
texts = data["Текст инцидента"].to_list()
labels = list(data["Группа тем"].value_counts().keys())
expanded_labels = ["{} ({})".format(label, ', '.join(synonyms[label])) for label in labels]

# %%
MODELS = [("MoritzLaurer/mDeBERTa-v3-base-mnli-xnli", "mdbrt_xnl"), ('cointegrated/rubert-base-cased-nli-threeway', "rbrt_3")]

# %%
for model_info in MODELS:
    hugging_name, name = model_info
    tokenizer = AutoTokenizer.from_pretrained(hugging_name)
    model = AutoModelForSequenceClassification.from_pretrained(hugging_name)

    if torch.cuda.is_available():
        model.cuda()

    labels_ = [f"{name}_{label}" for label in labels]
    zero_shot = []

    for text in tqdm(texts):
        zero_shot.append(dict(zip(labels_, predict_zero_shot(text, expanded_labels, model, tokenizer, label='entailment', normalize=True))))
    
    texts_df = pd.DataFrame(zero_shot)
    df_res = pd.concat([data, texts_df], axis=1)

    df_res.to_csv(f"data/{name}_train.csv", index=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:473: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# 100%|██████████| 22530/22530 [12:49<00:00, 29.28it/s]
# 100%|██████████| 22530/22530 [07:37<00:00, 49.25it/s]

# %%
df_res
# Out:
#                                 Исполнитель                        Группа тем  \
# 0               Лысьвенский городской округ                   Благоустройство
# 1      Министерство социального развития ПК  Социальное обслуживание и защита
# 2      Министерство социального развития ПК  Социальное обслуживание и защита
# 3                               Город Пермь            Общественный транспорт
# 4              Министерство здравоохранения          Здравоохранение/Медицина
# ...                                     ...                               ...
# 22525  Министерство социального развития ПК  Социальное обслуживание и защита
# 22526           Губахинский городской округ                               ЖКХ
# 22527          Министерство здравоохранения          Здравоохранение/Медицина
# 22528           Лысьвенский городской округ                   Благоустройство
# 22529  Министерство социального развития ПК  Социальное обслуживание и защита
#
#                                          Текст инцидента  \
# 0       Добрый день. Сегодня, 20.08.22, моя мать шла ...
# 1       Пермь г, 79194692145. В Перми с ноября 2021 г...
# 2       Добрый день . Скажите пожалуйста если подовал...
# 3       Каждая из них не о чем. Люди на остановках хо...
# 4       В Березниках у сына привитого откоронавируса ...
# ...                                                  ...
# 22525   , а если ещё не погасили ипотеку, но площадь ...
# 22526   Город Гремячинск ситуация с теплом на улице Л...
# 22527   Здравствуйте у меня ребёнку 2 месяца , тест н...
# 22528   А что творится с благоустройством дворов. Воо...
# 22529   Здравствуйте, подскажите пожалуйста. Сколько ...
#
#                                                   Тема  \
# 0                                      ★ Ямы во дворах
# 1                            Оказание гос. соц. помощи
# 2                             Дети и многодетные семьи
# 3                                 Содержание остановок
# 4      Технические проблемы с записью на прием к врачу
# ...                                                ...
# 22525                       Улучшение жилищных условий
# 22526   Ненадлежащее качество или отсутствие отопления
# 22527  Технические проблемы с записью на прием к врачу
# 22528            Благоустройство придомовых территорий
# 22529                        Оказание гос. соц. помощи
#
#        rbrt_3_Здравоохранение/Медицина  \
# 0                             0.048705
# 1                             0.084328
# 2                             0.101843
# 3                             0.015793
# 4                             0.140910
# ...                                ...
# 22525                         0.036109
# 22526                         0.026174
# 22527                         0.102063
# 22528                         0.013562
# 22529                         0.112169
#
#        rbrt_3_Социальное обслуживание и защита  rbrt_3_Дороги  rbrt_3_ЖКХ  \
# 0                                     0.052714       0.161883    0.022284
# 1                                     0.050574       0.169336    0.024782
# 2                                     0.094698       0.088189    0.021134
# 3                                     0.023579       0.152098    0.064346
# 4                                     0.090894       0.062690    0.008866
# ...                                        ...            ...         ...
# 22525                                 0.064556       0.092026    0.022015
# 22526                                 0.021576       0.215687    0.104945
# 22527                                 0.161751       0.116437    0.003653
# 22528                                 0.042138       0.134871    0.083667
# 22529                                 0.166049       0.060079    0.023686
#
#        rbrt_3_Благоустройство  rbrt_3_Мусор/Свалки/ТКО  ...  rbrt_3_Культура  \
# 0                    0.047180                 0.007163  ...         0.022664
# 1                    0.006744                 0.025475  ...         0.014172
# 2                    0.008967                 0.010250  ...         0.064134
# 3                    0.005393                 0.007394  ...         0.006972
# 4                    0.008660                 0.007999  ...         0.030991
# ...                       ...                      ...  ...              ...
# 22525                0.011203                 0.013414  ...         0.014991
# 22526                0.045970                 0.012817  ...         0.014203
# 22527                0.006009                 0.001943  ...         0.046069
# 22528                0.055239                 0.030713  ...         0.014725
# 22529                0.011322                 0.004931  ...         0.034734
#
#        rbrt_3_Электроснабжение  rbrt_3_Экономика и бизнес  rbrt_3_Экология  \
# 0                     0.053838                   0.005230         0.015606
# 1                     0.081784                   0.034773         0.010710
# 2                     0.078602                   0.042157         0.018911
# 3                     0.113489                   0.020463         0.010554
# 4                     0.073589                   0.017472         0.008722
# ...                        ...                        ...              ...
# 22525                 0.082175                   0.065991         0.016040
# 22526                 0.108728                   0.006279         0.014423
# 22527                 0.032656                   0.016048         0.015095
# 22528                 0.030569                   0.010481         0.038122
# 22529                 0.040532                   0.016114         0.039104
#
#        rbrt_3_Роспотребнадзор  \
# 0                    0.007825
# 1                    0.009292
# 2                    0.006296
# 3                    0.006124
# 4                    0.020612
# ...                       ...
# 22525                0.001908
# 22526                0.002831
# 22527                0.010671
# 22528                0.009268
# 22529                0.011336
#
#        rbrt_3_Памятники и объекты культурного наследия  \
# 0                                             0.026431
# 1                                             0.019509
# 2                                             0.019397
# 3                                             0.014456
# 4                                             0.020572
# ...                                                ...
# 22525                                         0.014138
# 22526                                         0.030243
# 22527                                         0.015194
# 22528                                         0.054543
# 22529                                         0.045106
#
#        rbrt_3_Государственная собственность  rbrt_3_Торговля  \
# 0                                  0.010285         0.013577
# 1                                  0.031808         0.046866
# 2                                  0.017114         0.068213
# 3                                  0.017669         0.083023
# 4                                  0.026373         0.031598
# ...                                     ...              ...
# 22525                              0.012725         0.155337
# 22526                              0.008356         0.049310
# 22527                              0.007638         0.018427
# 22528                              0.023219         0.011894
# 22529                              0.023294         0.056237
#
#        rbrt_3_МФЦ "Мои документы"  rbrt_3_Погребение и похоронное дело
# 0                        0.005685                             0.025486
# 1                        0.002858                             0.005327
# 2                        0.011773                             0.009154
# 3                        0.034779                             0.001617
# 4                        0.011618                             0.021792
# ...                           ...                                  ...
# 22525                    0.007212                             0.009298
# 22526                    0.003079                             0.001506
# 22527                    0.009114                             0.007993
# 22528                    0.005213                             0.001070
# 22529                    0.007902                             0.003768
#
# [22530 rows x 30 columns]

# %%
zero_shot = []

for text in tqdm(texts):
    zero_shot.append(dict(zip(labels_, predict_zero_shot(text, expanded_labels, model, tokenizer, label='entailment', normalize=True))))
# Out:
#   1%|          | 224/22530 [00:10<18:12, 20.42it/s]

# %%
texts_df = pd.DataFrame(zero_shot)

# %%
df_res = pd.concat([data, texts_df], axis=1)

# %%
df_res.head(3)
# Out:
#                             Исполнитель                        Группа тем  \
# 0           Лысьвенский городской округ                   Благоустройство
# 1  Министерство социального развития ПК  Социальное обслуживание и защита
# 2  Министерство социального развития ПК  Социальное обслуживание и защита
#
#                                      Текст инцидента  \
# 0   Добрый день. Сегодня, 20.08.22, моя мать шла ...
# 1   Пермь г, 79194692145. В Перми с ноября 2021 г...
# 2   Добрый день . Скажите пожалуйста если подовал...
#
#                         Тема  Здравоохранение/Медицина  \
# 0            ★ Ямы во дворах                  0.032651
# 1  Оказание гос. соц. помощи                  0.049973
# 2   Дети и многодетные семьи                  0.045039
#
#    Социальное обслуживание и защита    Дороги       ЖКХ  Благоустройство  \
# 0                          0.038203  0.095653  0.033030         0.169776
# 1                          0.056974  0.057099  0.050486         0.051638
# 2                          0.047977  0.047473  0.048638         0.049333
#
#    Мусор/Свалки/ТКО  ...  Культура  Электроснабжение  Экономика и бизнес  \
# 0          0.016031  ...  0.016146          0.027807            0.033891
# 1          0.046177  ...  0.016504          0.044984            0.055208
# 2          0.047752  ...  0.037862          0.044122            0.047773
#
#    Экология  Роспотребнадзор  Памятники и объекты культурного наследия  \
# 0  0.030938         0.027881                                  0.020490
# 1  0.045229         0.001087                                  0.004695
# 2  0.047779         0.015893                                  0.002648
#
#    Государственная собственность  Торговля  МФЦ "Мои документы"  \
# 0                       0.017793  0.029376             0.031591
# 1                       0.042820  0.055389             0.005975
# 2                       0.024886  0.047282             0.021684
#
#    Погребение и похоронное дело
# 0                      0.041036
# 1                      0.051682
# 2                      0.049017
#
# [3 rows x 30 columns]

# %%
data[:2]
# Out:
#                             Исполнитель                        Группа тем  \
# 0           Лысьвенский городской округ                   Благоустройство
# 1  Министерство социального развития ПК  Социальное обслуживание и защита
#
#                                      Текст инцидента  \
# 0   Добрый день. Сегодня, 20.08.22, моя мать шла ...
# 1   Пермь г, 79194692145. В Перми с ноября 2021 г...
#
#                         Тема
# 0            ★ Ямы во дворах
# 1  Оказание гос. соц. помощи

# %%
data[:2]["Текст инцидента"].to_list()
# Out:
# [' Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.Уважаемая Администрация, сделайте с этим что нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо.',
#  ' Пермь г, 79194692145. В Перми с ноября 2021 года не работает социальное такси. Каким образом можно получить льготу по проезду в такси в соц учреждения инвалиду 2гр.пррезд в общественном транспорте не возможен. Да и проездного льготного не представляется']

# %%
# Вывод топ-3 из каждого словаря
for text, (i, dictionary) in zip(data[:5].iterrows(), enumerate(zero_shot, 1)):
    print(text[1]["Группа тем"], text[1]["Текст инцидента"], sep='\n')
# Out:
# Благоустройство
#  Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.Уважаемая Администрация, сделайте с этим что нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо.
#
# Топ 3 для словаря 1:
# Благоустройство: 0.16977643966674805
# Дороги: 0.09565259516239166
# Безопасность: 0.07006222754716873
#
#
# ----------
# Социальное обслуживание и защита
#  Пермь г, 79194692145. В Перми с ноября 2021 года не работает социальное такси. Каким образом можно получить льготу по проезду в такси в соц учреждения инвалиду 2гр.пррезд в общественном транспорте не возможен. Да и проездного льготного не представляется
#
# Топ 3 для словаря 2:
# Общественный транспорт: 0.05749836936593056
# Дороги: 0.057098791003227234
# Социальное обслуживание и защита: 0.056974463164806366
#
#
# ----------
# Социальное обслуживание и защита
#  Добрый день . Скажите пожалуйста если подовала на пособие с 3 до 7 2 декабря , когда можно повторно подать ? вроде за 30 дней можно
#
# Топ 3 для словаря 3:
# Благоустройство: 0.049332644790410995
# Спецпроекты: 0.04916480556130409
# Погребение и похоронное дело: 0.049017053097486496
#
#
# ----------
# Общественный транспорт
#  Каждая из них не о чем. Люди на остановках хотят укрыться от непогоды или слишком погоды. Присесть, поставить сумку. Лавочки на полторы попы? Отсутствие или намек на присутствие спинки? Конструкторы, понятно, что не ждут транспорт на остановках. А гаджеты заряжать дома надо. Интерактивные панели и близко не нужны. У каждого в руках телефоны информации вагон. Разместить коды для быстрого доступа на ресурсы и сайты по транспорту хватит.
#
# Топ 3 для словаря 4:
# Общественный транспорт: 0.5156893134117126
# Спецпроекты: 0.17622262239456177
# Благоустройство: 0.16102486848831177
#
#
# ----------
# Здравоохранение/Медицина
#  В Березниках у сына привитого откоронавируса заболел пытались попасть на прием очередь в замкнутом пространстве бесподобна прямое вредителбское отношение к людям он не смог попасть на прием что делать на работу с т ой 37.8 не пускают и на прием не попасть .что вы мин здрав ДЕЛАЕТЕ ?
#
# Топ 3 для словаря 5:
# Дороги: 0.04298844188451767
# Спецпроекты: 0.04289195314049721
# Благоустройство: 0.042579587548971176
#
#
# ----------

# %%
    top_3 = sorted(dictionary.items(), key=lambda item: item[1], reverse=True)[:3]
    print(f"\nТоп 3 для словаря {i}:")
    
    for term, value in top_3:
        print(f"{term}: {value}")
    print("\n")  # Добавим пустую строку для разделения вывода для разных словарей
    print('-'*10)

# %%
zero_shot
# Out:
# [{'Здравоохранение/Медицина': 0.07243349,
#   'Социальное обслуживание и защита': 0.057399888,
#   'Дороги': 0.1599418,
#   'ЖКХ': 0.022017324,
#   'Благоустройство': 0.046614457,
#   'Мусор/Свалки/ТКО': 0.0070770737,
#   'Общественный транспорт': 0.12572664,
#   'Коронавирус': 0.03670317,
#   'Образование': 0.008089678,
#   'Безопасность': 0.13498378,
#   'Связь и телевидение': 0.024683768,
#   'Мобилизация': 0.0012552217,
#   'Физическая культура и спорт': 0.07612989,
#   'Строительство и архитектура': 0.010305518,
#   'Газ и топливо': 0.0149787385,
#   'Спецпроекты': 0.017268587,
#   'Культура': 0.02239249,
#   'Электроснабжение': 0.053192865,
#   'Экономика и бизнес': 0.0051672845,
#   'Экология': 0.015419055,
#   'Роспотребнадзор': 0.007731632,
#   'Памятники и объекты культурного наследия': 0.0261142,
#   'Государственная собственность': 0.010161442,
#   'Торговля': 0.01341474,
#   'МФЦ "Мои документы"': 0.0056168595,
#   'Погребение и похоронное дело': 0.025180386},
#  {'Здравоохранение/Медицина': 0.12884903,
#   'Социальное обслуживание и защита': 0.047844693,
#   'Дороги': 0.15590234,
#   'ЖКХ': 0.022816235,
#   'Благоустройство': 0.0062090564,
#   'Мусор/Свалки/ТКО': 0.023454297,
#   'Общественный транспорт': 0.25699514,
#   'Коронавирус': 0.007450862,
#   'Образование': 0.009714492,
#   'Безопасность': 0.0100659365,
#   'Связь и телевидение': 0.018468704,
#   'Мобилизация': 0.002435555,
#   'Физическая культура и спорт': 0.021959405,
#   'Строительство и архитектура': 0.019908786,
#   'Газ и топливо': 0.026479008,
#   'Спецпроекты': 0.004745837,
#   'Культура': 0.013047592,
#   'Электроснабжение': 0.07529572,
#   'Экономика и бизнес': 0.03201396,
#   'Экология': 0.009860072,
#   'Роспотребнадзор': 0.0085550435,
#   'Памятники и объекты культурного наследия': 0.017960927,
#   'Государственная собственность': 0.029284216,
#   'Торговля': 0.04314805,
#   'МФЦ "Мои документы"': 0.0026308084,
#   'Погребение и похоронное дело': 0.0049042073},
#  {'Здравоохранение/Медицина': 0.08086726,
#   'Социальное обслуживание и защита': 0.10491933,
#   'Дороги': 0.08839802,
#   'ЖКХ': 0.021183943,
#   'Благоустройство': 0.008987736,
#   'Мусор/Свалки/ТКО': 0.010274547,
#   'Общественный транспорт': 0.051818125,
#   'Коронавирус': 0.004801281,
#   'Образование': 0.036277033,
#   'Безопасность': 0.024746139,
#   'Связь и телевидение': 0.045233134,
#   'Мобилизация': 0.01592563,
#   'Физическая культура и спорт': 0.09974265,
#   'Строительство и архитектура': 0.02218706,
#   'Газ и топливо': 0.037274018,
#   'Спецпроекты': 0.010818564,
#   'Культура': 0.06428593,
#   'Электроснабжение': 0.07878767,
#   'Экономика и бизнес': 0.042256985,
#   'Экология': 0.018956143,
#   'Роспотребнадзор': 0.006311267,
#   'Памятники и объекты культурного наследия': 0.019442553,
#   'Государственная собственность': 0.017154047,
#   'Торговля': 0.06837449,
#   'МФЦ "Мои документы"': 0.011800836,
#   'Погребение и похоронное дело': 0.009175622}]

# %%
data[:3]
# Out:
#                             Исполнитель                        Группа тем  \
# 0           Лысьвенский городской округ                   Благоустройство
# 1  Министерство социального развития ПК  Социальное обслуживание и защита
# 2  Министерство социального развития ПК  Социальное обслуживание и защита
#
#                                      Текст инцидента  \
# 0   Добрый день. Сегодня, 20.08.22, моя мать шла ...
# 1   Пермь г, 79194692145. В Перми с ноября 2021 г...
# 2   Добрый день . Скажите пожалуйста если подовал...
#
#                         Тема
# 0            ★ Ямы во дворах
# 1  Оказание гос. соц. помощи
# 2   Дети и многодетные семьи

# %%
list(data.iloc[:3]["Текст инцидента"])
# Out:
# [' Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.Уважаемая Администрация, сделайте с этим что нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо.',
#  ' Пермь г, 79194692145. В Перми с ноября 2021 года не работает социальное такси. Каким образом можно получить льготу по проезду в такси в соц учреждения инвалиду 2гр.пррезд в общественном транспорте не возможен. Да и проездного льготного не представляется',
#  ' Добрый день . Скажите пожалуйста если подовала на пособие с 3 до 7 2 декабря , когда можно повторно подать ? вроде за 30 дней можно']

# %%
zero_shot[2]
# Out:
# {'Здравоохранение/Медицина': 0.0369621,
#  'Социальное обслуживание и защита': 0.08136316,
#  'Дороги': 0.060928594,
#  'ЖКХ': 0.0012773033,
#  'Благоустройство': 0.013771566,
#  'Мусор/Свалки/ТКО': 0.03410873,
#  'Общественный транспорт': 0.00032323206,
#  'Коронавирус': 0.00041167648,
#  'Образование': 0.00071735826,
#  'Безопасность': 0.00058839784,
#  'Связь и телевидение': 0.0017441931,
#  'Мобилизация': 0.24488316,
#  'Физическая культура и спорт': 0.0033227406,
#  'Строительство и архитектура': 0.0052733435,
#  'Газ и топливо': 0.008030815,
#  'Спецпроекты': 0.24313308,
#  'Культура': 0.0008101569,
#  'Электроснабжение': 0.0029854586,
#  'Экономика и бизнес': 0.001905556,
#  'Экология': 0.00063697476,
#  'Роспотребнадзор': 0.00092287146,
#  'Памятники и объекты культурного наследия': 0.001229014,
#  'Государственная собственность': 0.13127658,
#  'Торговля': 0.09587384,
#  'МФЦ "Мои документы"': 0.0022251587,
#  'Погребение и похоронное дело': 0.025294904}

# %%
", ".join(labels)
# Out:
# 'Здравоохранение/Медицина, Социальное обслуживание и защита, Дороги, ЖКХ, Благоустройство, Мусор/Свалки/ТКО, Общественный транспорт, Коронавирус, Образование, Безопасность, Связь и телевидение, Мобилизация, Физическая культура и спорт, Строительство и архитектура, Газ и топливо, Спецпроекты, Культура, Электроснабжение, Экономика и бизнес, Экология, Роспотребнадзор, Памятники и объекты культурного наследия, Государственная собственность, Торговля, МФЦ "Мои документы", Погребение и похоронное дело'

# %%
show_data = []
for batch in tqdm(batches):
    output = classifier(batch, labels, multi_label=False)
    result = get_dicts(output)
    show_data.extend(result)
# Out:
#   0%|          | 5/1409 [01:30<6:52:02, 17.61s/it]

# %%
print(data.iloc[0]["Текст инцидента"])
# Out:
#  Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.Уважаемая Администрация, сделайте с этим что нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо.

# %%
data["Группа тем"]
# Out:
# 0                         Благоустройство
# 1        Социальное обслуживание и защита
# 2        Социальное обслуживание и защита
# 3                  Общественный транспорт
# 4                Здравоохранение/Медицина
#                        ...
# 22525    Социальное обслуживание и защита
# 22526                                 ЖКХ
# 22527            Здравоохранение/Медицина
# 22528                     Благоустройство
# 22529    Социальное обслуживание и защита
# Name: Группа тем, Length: 22530, dtype: object

# %%
show_data
# Out:
# [{'Дороги': 0.4742022156715393,
#   'Благоустройство': 0.3620149791240692,
#   'Безопасность': 0.11064452677965164,
#   'Мобилизация': 0.02219863422214985,
#   'Государственная собственность': 0.0056534986943006516,
#   'Общественный транспорт': 0.005497244652360678,
#   'ЖКХ': 0.0028140961658209562,
#   'Электроснабжение': 0.0025275512598454952,
#   'Социальное обслуживание и защита': 0.002205977449193597,
#   'Здравоохранение/Медицина': 0.001733725075609982,
#   'Погребение и похоронное дело': 0.001085619325749576,
#   'Газ и топливо': 0.0010614615166559815,
#   'Спецпроекты': 0.0010354158002883196,
#   'Строительство и архитектура': 0.000891435076482594,
#   'Роспотребнадзор': 0.0007872450514696538,
#   'Экономика и бизнес': 0.0006987701053731143,
#   'Памятники и объекты культурного наследия': 0.0006359101971611381,
#   'Культура': 0.0006162405479699373,
#   'Связь и телевидение': 0.0005868949228897691,
#   'Торговля': 0.0005605738260783255,
#   'Мусор/Свалки/ТКО': 0.00046806089812889695,
#   'Экология': 0.00045743855298496783,
#   'Образование': 0.00044078475912101567,
#   'МФЦ "Мои документы"': 0.00042728387052193284,
#   'Коронавирус': 0.00041746482020244,
#   'Физическая культура и спорт': 0.0003369992191437632},
#  {'Дороги': 0.5742022395133972,
#   'Общественный транспорт': 0.17396947741508484,
#   'Социальное обслуживание и защита': 0.03982904180884361,
#   'Мобилизация': 0.021060418337583542,
#   'Спецпроекты': 0.017788900062441826,
#   'Экономика и бизнес': 0.015302412211894989,
#   'Мусор/Свалки/ТКО': 0.013936502858996391,
#   'Здравоохранение/Медицина': 0.012057941406965256,
#   'Государственная собственность': 0.01194592285901308,
#   'ЖКХ': 0.011284342035651207,
#   'Безопасность': 0.01125565730035305,
#   'Газ и топливо': 0.010531376115977764,
#   'Строительство и архитектура': 0.01041345950216055,
#   'Коронавирус': 0.009938718751072884,
#   'Памятники и объекты культурного наследия': 0.009191651828587055,
#   'МФЦ "Мои документы"': 0.007678472436964512,
#   'Благоустройство': 0.00730048818513751,
#   'Экология': 0.0071463496424257755,
#   'Связь и телевидение': 0.006441881414502859,
#   'Роспотребнадзор': 0.0064139110036194324,
#   'Погребение и похоронное дело': 0.005213398020714521,
#   'Образование': 0.004313622135668993,
#   'Культура': 0.003328838152810931,
#   'Электроснабжение': 0.003273300128057599,
#   'Торговля': 0.0031009444501250982,
#   'Физическая культура и спорт': 0.003080755937844515},
#   'Строительство и архитектура': 0.002918458776548505,
#   'Физическая культура и спорт': 0.002726212376728654,
#   'Погребение и похоронное дело': 0.0024838666431605816,
#   'Общественный транспорт': 0.0024408334866166115,
#   'Культура': 0.002371510723605752},
#  {'Государственная собственность': 0.24733079969882965,
#   'Дороги': 0.16909803450107574,
#   'Мобилизация': 0.13635164499282837,
#   'Здравоохранение/Медицина': 0.0878356397151947,
#   'Спецпроекты': 0.05516646057367325,
#   'Социальное обслуживание и защита': 0.053145091980695724,
#   'Благоустройство': 0.03249911591410637,
#   'Безопасность': 0.02833709493279457,
#   'Памятники и объекты культурного наследия': 0.026967288926243782,
#   'Связь и телевидение': 0.02639702893793583,
#   'Культура': 0.022196831181645393,
#   'ЖКХ': 0.02178410068154335,
#   'Экономика и бизнес': 0.008887659758329391,
#   'Коронавирус': 0.00887705571949482,
#   'Мусор/Свалки/ТКО': 0.00852617435157299,
#   'Газ и топливо': 0.008480292744934559,
#   'Общественный транспорт': 0.008449986577033997,
#   'Торговля': 0.00804387591779232,
#   'Погребение и похоронное дело': 0.007840851321816444,
#   'Роспотребнадзор': 0.006038833409547806,
#   'Электроснабжение': 0.005463435780256987,
#   'Строительство и архитектура': 0.005259734112769365,
#   'Экология': 0.0051475027576088905,
#   'МФЦ "Мои документы"': 0.004622701555490494,
#   'Образование': 0.0038554409984499216,
#   'Физическая культура и спорт': 0.0033974256366491318},
#  {'Дороги': 0.16147726774215698,
#   'Мобилизация': 0.14539086818695068,
#   'Мусор/Свалки/ТКО': 0.0739232525229454,
#   'Спецпроекты': 0.05868416279554367,
#   'Строительство и архитектура': 0.05678435415029526,
#   'ЖКХ': 0.048667073249816895,
#   'Безопасность': 0.04417920485138893,
#   'Здравоохранение/Медицина': 0.0439884178340435,
#   'Экономика и бизнес': 0.042751580476760864,
#   'Экология': 0.039733730256557465,
#   'Благоустройство': 0.03954951837658882,
#   'Погребение и похоронное дело': 0.03493331000208855,
#   'Газ и топливо': 0.034723784774541855,
#   'Государственная собственность': 0.027576405555009842,
#   'Памятники и объекты культурного наследия': 0.025398878380656242,
#   'Связь и телевидение': 0.02225213125348091,
#   'Физическая культура и спорт': 0.015125799924135208,
#   'Социальное обслуживание и защита': 0.013248358853161335,
#   'Образование': 0.01130678877234459,
#   'Коронавирус': 0.010377008467912674,
#   'МФЦ "Мои документы"': 0.009707465767860413,
#   'Общественный транспорт': 0.00933410320430994,
#   'Торговля': 0.008617310784757137,
#   'Культура': 0.007899623364210129,
#   'Электроснабжение': 0.00770471291616559,
#   'Роспотребнадзор': 0.006664943881332874},
#  {'Мобилизация': 0.27528202533721924,
#   'Спецпроекты': 0.24038217961788177,
#   'Образование': 0.09145589917898178,
#   'Государственная собственность': 0.0531793050467968,
#   'Социальное обслуживание и защита': 0.04678360000252724,
#   'Памятники и объекты культурного наследия': 0.029724569991230965,
#   'Здравоохранение/Медицина': 0.028854019939899445,
#   'Экономика и бизнес': 0.02575104311108589,
#   'Благоустройство': 0.02486155927181244,
#   'МФЦ "Мои документы"': 0.019880205392837524,
#   'Мусор/Свалки/ТКО': 0.02749684825539589,
#   'Связь и телевидение': 0.026401085779070854,
#   'Газ и топливо': 0.02637851983308792,
#   'Образование': 0.0256122387945652,
#   'Культура': 0.025584761053323746,
#   'Строительство и архитектура': 0.024017464369535446,
#   'Роспотребнадзор': 0.023285625502467155,
#   'Физическая культура и спорт': 0.022244008257985115,
#   'Экология': 0.02173398993909359,
#   'Электроснабжение': 0.020652862265706062,
#   'Торговля': 0.020373305305838585,
#   'Общественный транспорт': 0.018665790557861328,
#   'Безопасность': 0.014970618300139904},
#  {'Мобилизация': 0.23669838905334473,
#   'Дороги': 0.20334137976169586,
#   'Социальное обслуживание и защита': 0.04429353028535843,
#   'Спецпроекты': 0.0356769897043705,
#   'Строительство и архитектура': 0.03561777621507645,
#   'Экономика и бизнес': 0.032760705798864365,
#   'Погребение и похоронное дело': 0.032512638717889786,
#   'Газ и топливо': 0.030504362657666206,
#   'Связь и телевидение': 0.03009926900267601,
#   'Государственная собственность': 0.028580617159605026,
#   'Здравоохранение/Медицина': 0.026980316266417503,
#   'Мусор/Свалки/ТКО': 0.026666423305869102,
#   'Памятники и объекты культурного наследия': 0.02551346831023693,
#   'Физическая культура и спорт': 0.025502702221274376,
#   'Торговля': 0.02280525490641594,
#   'МФЦ "Мои документы"': 0.02046426199376583,
#   'ЖКХ': 0.017363497987389565,
#   'Благоустройство': 0.01684987172484398,
#   'Электроснабжение': 0.016068654134869576,
#   'Образование': 0.015377367846667767,
#   'Культура': 0.01507286261767149,
#   'Коронавирус': 0.014826838858425617,
#   'Экология': 0.013182971626520157,
#   'Безопасность': 0.012612900696694851,
#   'Общественный транспорт': 0.011235816404223442,
#   'Роспотребнадзор': 0.009391275234520435},
#  {'Дороги': 0.3552820682525635,
#   'Общественный транспорт': 0.3349752128124237,
#   'Мобилизация': 0.122603639960289,
#   'Строительство и архитектура': 0.03564000874757767,
#   'Благоустройство': 0.028014706447720528,
#   'Связь и телевидение': 0.015037977136671543,
#   'Экономика и бизнес': 0.014975829981267452,
#   'Торговля': 0.009615940973162651,
#   'Здравоохранение/Медицина': 0.008564948104321957,
#   'ЖКХ': 0.008071573451161385,
#   'Экология': 0.007853069342672825,
#   'Погребение и похоронное дело': 0.007819228805601597,
#   'Памятники и объекты культурного наследия': 0.007156771142035723,
#   'Культура': 0.006646779365837574,
#   'Спецпроекты': 0.0064993491396307945,
#   'Государственная собственность': 0.006377529818564653,
#   'Образование': 0.00565268425270915,
#   'Социальное обслуживание и защита': 0.004586298018693924,
#   'Газ и топливо': 0.0036337575875222683,
#   'Безопасность': 0.003395449835807085,
#   'Мусор/Свалки/ТКО': 0.0028541679494082928,
#   'Физическая культура и спорт': 0.0025521721690893173,
#   'МФЦ "Мои документы"': 0.0008392746676690876,
#   'Электроснабжение': 0.0006733459886163473,
#   'Коронавирус': 0.00038374916766770184,
#   'Роспотребнадзор': 0.0002944573061540723},
#  {'Дороги': 0.4978035092353821,
#   'Газ и топливо': 0.23160724341869354,
#   'Электроснабжение': 0.15637634694576263,
#   'Государственная собственность': 0.029953250661492348,
#   'Мобилизация': 0.018725324422121048,
#   'ЖКХ': 0.017804231494665146,
#   'Строительство и архитектура': 0.012564733624458313,
#   'Спецпроекты': 0.006697657518088818,
#   'Экономика и бизнес': 0.006302459631115198,
#   'Благоустройство': 0.0054382625967264175,
#   'Мусор/Свалки/ТКО': 0.0036783188115805387,
#   'Связь и телевидение': 0.0016566948033869267,
#   'Общественный транспорт': 0.0014361502835527062,
#   'Коронавирус': 0.001426874427124858,
#   'Экология': 0.0011293514398857951,
#   'Погребение и похоронное дело': 0.001075345673598349,
#   'Здравоохранение/Медицина': 0.0009997617453336716,
#   'Памятники и объекты культурного наследия': 0.0009948713704943657,
#   'Безопасность': 0.0009083074983209372,
#   'Социальное обслуживание и защита': 0.0008913038764148951,
#   'Торговля': 0.0005263243219815195,
#   'Физическая культура и спорт': 0.0005155758699402213,
#   'МФЦ "Мои документы"': 0.0005058469250798225,
#   'Культура': 0.0004103011160623282,
#   'Образование': 0.0003398256958462298,
#   'Роспотребнадзор': 0.00023217435227707028},
#  {'Мусор/Свалки/ТКО': 0.4817168712615967,
#   'Мобилизация': 0.3208973705768585,
#   'Дороги': 0.07584062963724136,
#   'Благоустройство': 0.050747886300086975,
#   'Общественный транспорт': 0.025354141369462013,
#   'Спецпроекты': 0.01591108925640583,
#   'Экология': 0.007684711366891861,
#   'Торговля': 0.003742554225027561,
#   'Строительство и архитектура': 0.003235775511711836,
#   'Социальное обслуживание и защита': 0.00297980522736907,
#   'Экономика и бизнес': 0.0016411544056609273,
#   'Газ и топливо': 0.0015834515215829015,
#   'ЖКХ': 0.0012203765800222754,
#   'Безопасность': 0.001194098382256925,
#   'Культура': 0.001123496680520475,
#   'Погребение и похоронное дело': 0.001086871838197112,
#   'Связь и телевидение': 0.0008937232778407633,
#   'Государственная собственность': 0.0008741472847759724,
#   'Памятники и объекты культурного наследия': 0.0003603574587032199,
#   'Коронавирус': 0.00034599582431837916,
#   'Физическая культура и спорт': 0.00033262561191804707,
#   'Электроснабжение': 0.0002939476980827749,
#   'МФЦ "Мои документы"': 0.0002717860334087163,
#   'Здравоохранение/Медицина': 0.0002548067714087665,
#   'Роспотребнадзор': 0.00021437485702335835,
#   'Образование': 0.00019793130923062563},
#  {'Здравоохранение/Медицина': 0.130438894033432,
#   'Памятники и объекты культурного наследия': 0.11473493278026581,
#   'Экономика и бизнес': 0.06981625407934189,
#   'Физическая культура и спорт': 0.05143875256180763,
#   'Погребение и похоронное дело': 0.0481107272207737,
#   'Строительство и архитектура': 0.04410812631249428,
#   'Социальное обслуживание и защита': 0.04389055818319321,
#   'Связь и телевидение': 0.041829727590084076,
#   'Мобилизация': 0.03926784172654152,
#   'Коронавирус': 0.038626812398433685,
#   'Газ и топливо': 0.03859701752662659,
#   'Спецпроекты': 0.03751411288976669,
#   'Дороги': 0.03204978257417679,
#   'Государственная собственность': 0.031633004546165466,
#   'МФЦ "Мои документы"': 0.029342006891965866,
#   'Мусор/Свалки/ТКО': 0.027680886909365654,
#   'Роспотребнадзор': 0.02406451292335987,
#   'Образование': 0.021918687969446182,
#   'Благоустройство': 0.021394366398453712,
#   'Безопасность': 0.018883470445871353,
#   'Культура': 0.01858634129166603,
#   'Электроснабжение': 0.018311329185962677,
#   'Торговля': 0.01812690496444702,
#   'Экология': 0.015949873253703117,
#   'Общественный транспорт': 0.012939839623868465,
#   'ЖКХ': 0.010745245963335037},
#  {'Социальное обслуживание и защита': 0.12030161172151566,
#   'Экономика и бизнес': 0.07820101827383041,
#   'Мобилизация': 0.069364033639431,
#   'Связь и телевидение': 0.06878495961427689,
#   'Дороги': 0.05444364622235298,
#   'Спецпроекты': 0.05263936147093773,
#   'Строительство и архитектура': 0.048424672335386276,
#   'Здравоохранение/Медицина': 0.04174737259745598,
#   'Государственная собственность': 0.03867021203041077,
#   'Памятники и объекты культурного наследия': 0.03651749715209007,
#   'Газ и топливо': 0.031964726746082306,
#   'Образование': 0.031524330377578735,
#   'МФЦ "Мои документы"': 0.029695017263293266,
#   'Благоустройство': 0.029328487813472748,
#   'Безопасность': 0.029231775552034378,
#   'Коронавирус': 0.026686569675803185,
#   'Мусор/Свалки/ТКО': 0.025880565866827965,
#   'Физическая культура и спорт': 0.02451825886964798,
#   'Погребение и похоронное дело': 0.02347986027598381,
#   'Торговля': 0.02214716374874115,
#   'Культура': 0.021061403676867485,
#   'Электроснабжение': 0.02073640748858452,
#   'ЖКХ': 0.01948726177215576,
#   'Экология': 0.01913345232605934,
#   'Роспотребнадзор': 0.018995415419340134,
#   'Общественный транспорт': 0.017034994438290596},
#  {'Экология': 0.15068769454956055,
#   'Мусор/Свалки/ТКО': 0.13700123131275177,
#   'Газ и топливо': 0.1227308139204979,
#   'Государственная собственность': 0.10138244181871414,
#   'ЖКХ': 0.08803804218769073,
#   'Мобилизация': 0.06903945654630661,
#   'Электроснабжение': 0.04877278953790665,
#   'Дороги': 0.0477786585688591,
#   'Спецпроекты': 0.0380130410194397,
#   'Экономика и бизнес': 0.026375548914074898,
#   'Безопасность': 0.017377076670527458,
#   'Памятники и объекты культурного наследия': 0.016820644959807396,
#   'Коронавирус': 0.016138343140482903,
#   'МФЦ "Мои документы"': 0.014322178438305855,
#   'Благоустройство': 0.01327503938227892,
#   'Погребение и похоронное дело': 0.013014189898967743,
#   'Социальное обслуживание и защита': 0.010262339375913143,
#   'Культура': 0.009383120574057102,
#   'Связь и телевидение': 0.008803745731711388,
#   'Торговля': 0.007993917912244797,
#   'Здравоохранение/Медицина': 0.007979453541338444,
#   'Строительство и архитектура': 0.007581572514027357,
#   'Физическая культура и спорт': 0.0074808779172599316,
#   'Образование': 0.007262085564434528,
#   'Общественный транспорт': 0.0069523402489721775,
#   'Роспотребнадзор': 0.005533276591449976},
#  {'Мобилизация': 0.7766427993774414,
#   'Безопасность': 0.06351396441459656,
#   'Дороги': 0.03457731753587723,
#   'Государственная собственность': 0.02061481401324272,
#   'Благоустройство': 0.016671758145093918,
#   'Спецпроекты': 0.011782549321651459,
#   'Мусор/Свалки/ТКО': 0.011704402044415474,
#   'Торговля': 0.008748652413487434,
#   'Здравоохранение/Медицина': 0.008559033274650574,
#   'Социальное обслуживание и защита': 0.005991245154291391,
#   'Погребение и похоронное дело': 0.005920336116105318,
#   'Экономика и бизнес': 0.004958722274750471,
#   'Газ и топливо': 0.0047960844822227955,
#   'Связь и телевидение': 0.0036843956913799047,
#   'Культура': 0.002731044078245759,
#   'Физическая культура и спорт': 0.0023150108754634857,
#   'Коронавирус': 0.0021770992316305637,
#   'Строительство и архитектура': 0.001988037023693323,
#   'Экология': 0.0018585554789751768,
#   'МФЦ "Мои документы"': 0.0017936216900125146,
#   'Роспотребнадзор': 0.0017927470616996288,
#   'Электроснабжение': 0.0016510781133547425,
#   'ЖКХ': 0.0016484438674524426,
#   'Памятники и объекты культурного наследия': 0.0016312131192535162,
#   'Общественный транспорт': 0.001317900838330388,
#   'Образование': 0.0009291303576901555},
#  {'Мобилизация': 0.09223730117082596,
#   'Спецпроекты': 0.08871560543775558,
#   'Благоустройство': 0.062380578368902206,
#   'Образование': 0.04593903198838234,
#   'Социальное обслуживание и защита': 0.04134399816393852,
#   'МФЦ "Мои документы"': 0.0409548282623291,
#   'Здравоохранение/Медицина': 0.04075469821691513,
#   'Экономика и бизнес': 0.040120743215084076,
#   'Связь и телевидение': 0.03737957030534744,
#   'Дороги': 0.03429218381643295,
#   'Газ и топливо': 0.03424477204680443,
#   'Памятники и объекты культурного наследия': 0.03380715101957321,
#   'Культура': 0.03352730721235275,
#   'ЖКХ': 0.033368904143571854,
#   'Мусор/Свалки/ТКО': 0.03312494605779648,
#   'Строительство и архитектура': 0.03305935859680176,
#   'Физическая культура и спорт': 0.03265939652919769,
#   'Государственная собственность': 0.03185247257351875,
#   'Коронавирус': 0.030300607904791832,
#   'Электроснабжение': 0.02997923083603382,
#   'Экология': 0.02959604002535343,
#   'Роспотребнадзор': 0.026792891323566437,
#   'Безопасность': 0.025825094431638718,
#   'Погребение и похоронное дело': 0.025274019688367844,
#   'Общественный транспорт': 0.022672360762953758,
#   'Торговля': 0.01979679800570011}]

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="valhalla/distilbart-mnli-12-1", device=0)

# %%
data.iloc[0]["Текст инцидента"]
# Out:
# ' Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.Уважаемая Администрация, сделайте с этим что нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо.'

# %%
sequence_to_classify = data.iloc[0]["Текст инцидента"]
candidate_labels = labels
output = classifier(sequence_to_classify, candidate_labels, multi_label=False)

# %%
get_dicts([output])
# Out:
# [{'Благоустройство': 0.0673627108335495,
#   'Коронавирус': 0.05220114067196846,
#   'Торговля': 0.049726326018571854,
#   'Дороги': 0.048627957701683044,
#   'Мобилизация': 0.04839465767145157,
#   'Мусор/Свалки/ТКО': 0.045927710831165314,
#   'Безопасность': 0.04461669921875,
#   'Культура': 0.04308779165148735,
#   'Здравоохранение/Медицина': 0.042335279285907745,
#   'Связь и телевидение': 0.041586291044950485,
#   'Экология': 0.03877926245331764,
#   'Спецпроекты': 0.038727931678295135,
#   'Роспотребнадзор': 0.03718283027410507,
#   'Образование': 0.03593577444553375,
#   'ЖКХ': 0.03519650921225548,
#   'Социальное обслуживание и защита': 0.03485891595482826,
#   'Газ и топливо': 0.03411963954567909,
#   'Электроснабжение': 0.033277422189712524,
#   'Физическая культура и спорт': 0.0329168327152729,
#   'Строительство и архитектура': 0.03284507244825363,
#   'Экономика и бизнес': 0.03197817504405975,
#   'Государственная собственность': 0.03111763671040535,
#   'Общественный транспорт': 0.028752202168107033,
#   'Погребение и похоронное дело': 0.026360511779785156,
#   'Памятники и объекты культурного наследия': 0.02624361217021942,
#   'МФЦ "Мои документы"': 0.017841199412941933}]

# %%
get

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_checkpoint = "MoritzLaurer/mDeBERTa-v3-base-mnli-xnli"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint)
if torch.cuda.is_available():
    model.cuda()
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:473: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
def predict_zero_shot(text, label_texts, model, tokenizer, label='entailment', normalize=True):
    label_texts
    tokens = tokenizer([text] * len(label_texts), label_texts, truncation=True, return_tensors='pt', padding=True)
    with torch.inference_mode():
        result = torch.softmax(model(**tokens.to(model.device)).logits, -1)
    proba = result[:, model.config.label2id[label]].cpu().numpy()
    if normalize:
        proba /= sum(proba)
    return proba

classes = labels
res = predict_zero_shot(data.iloc[0]["Текст инцидента"], classes, model, tokenizer)

# %%
dict(zip(labels, res))
# Out:
# {'Здравоохранение/Медицина': 0.00336944,
#  'Социальное обслуживание и защита': 0.54626316,
#  'Дороги': 0.0043771574,
#  'ЖКХ': 0.0046370993,
#  'Благоустройство': 0.005680582,
#  'Мусор/Свалки/ТКО': 0.0020164954,
#  'Общественный транспорт': 0.011570638,
#  'Коронавирус': 0.0018653381,
#  'Образование': 0.002354904,
#  'Безопасность': 0.044092167,
#  'Связь и телевидение': 0.0062241484,
#  'Мобилизация': 0.0150900455,
#  'Физическая культура и спорт': 0.0030005423,
#  'Строительство и архитектура': 0.0074633164,
#  'Газ и топливо': 0.013458099,
#  'Спецпроекты': 0.039699323,
#  'Культура': 0.0027449788,
#  'Электроснабжение': 0.18732905,
#  'Экономика и бизнес': 0.005688766,
#  'Экология': 0.0027789448,
#  'Роспотребнадзор': 0.00961375,
#  'Памятники и объекты культурного наследия': 0.0034370269,
#  'Государственная собственность': 0.06210282,
#  'Торговля': 0.0057876017,
#  'МФЦ "Мои документы"': 0.0028142086,
#  'Погребение и похоронное дело': 0.006540402}

# %%
labels
# Out:
# ['Здравоохранение/Медицина',
#  'Социальное обслуживание и защита',
#  'Дороги',
#  'ЖКХ',
#  'Благоустройство',
#  'Мусор/Свалки/ТКО',
#  'Общественный транспорт',
#  'Коронавирус',
#  'Образование',
#  'Безопасность',
#  'Связь и телевидение',
#  'Мобилизация',
#  'Физическая культура и спорт',
#  'Строительство и архитектура',
#  'Газ и топливо',
#  'Спецпроекты',
#  'Культура',
#  'Электроснабжение',
#  'Экономика и бизнес',
#  'Экология',
#  'Роспотребнадзор',
#  'Памятники и объекты культурного наследия',
#  'Государственная собственность',
#  'Торговля',
#  'МФЦ "Мои документы"',
#  'Погребение и похоронное дело']
