# %%
import pandas as pd

from transformers import T5ForConditionalGeneration, T5Tokenizer

from typing import List

from tqdm.notebook import tqdm

DEVICE = "cuda"

# %%
BAD_THEMES = ["Государственная собственность", "Культура", 'МФЦ "Мои документы"', 
              "Памятники и объекты культурного наследия", "Погребение и похоронное дело", 
              "Роспотребнадзор", "Спецпроекты", "Строительство и архитектура", "Торговля",
              "Физическая культура и спорт", "Экология", "Экономика и бизнес", "Электроснабжение"]

# %%
MODEL_NAME = 'cointegrated/rut5-base-paraphraser'

model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME).to(DEVICE)
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)

# %%
def paraphrase(texts: List[str], beams=5, grams=4, do_sample=True):
    x = tokenizer(texts, return_tensors='pt', padding=True).to(model.device)
    
    max_size = int(x.input_ids.shape[1] * 1.5 + 10)
    
    out = model.generate(**x, encoder_no_repeat_ngram_size=grams, num_beams=beams, max_length=max_size, do_sample=do_sample)
    
    return tokenizer.batch_decode(out, skip_special_tokens=True)


def generate_new_samples(original_sample: str, n_new_samples: int) -> List[str]:
    return paraphrase([original_sample for _ in range(n_new_samples)])


def generate_new_samples_in_dataset(data: pd.DataFrame, n_new_samples: int = 5, bad_themes: List[str] = BAD_THEMES) -> pd.DataFrame:
    dfs = []
    for _, row in tqdm(data.iterrows(), total=len(data)):
        df = pd.DataFrame(columns=data.columns)
        
        performer, group, text, theme = row["Исполнитель":"Тема"]

        new_samples = generate_new_samples(text, n_new_samples)

        df["Текст инцидента"] = new_samples
        df["Исполнитель"] = performer
        df["Группа тем"] = group
        df["Тема"] = theme

        dfs.append(df)

    return pd.concat(dfs)

# %%
data = pd.read_csv("../train_dataset_train_variant2.csv")

bad_data = data.copy()[data["Группа тем"].isin(BAD_THEMES)]
bad_data
# Out:
#                                              Исполнитель  \
# 29                                            АО ПРО ТКО
# 62                          Министерство здравоохранения
# 63     Александровский муниципальный округ Пермского ...
# 77                              Министерство образования
# 204                          Лысьвенский городской округ
# ...                                                  ...
# 22352                        Лысьвенский городской округ
# 22354                                        Город Пермь
# 22368                        Губахинский городской округ
# 22506                                        Город Пермь
# 22522                                            ИГЖН ПК
#
#                         Группа тем  \
# 29              Экономика и бизнес
# 62              Экономика и бизнес
# 63                        Культура
# 77                        Культура
# 204                    Спецпроекты
# ...                            ...
# 22352                     Культура
# 22354  Строительство и архитектура
# 22368  Физическая культура и спорт
# 22506                     Культура
# 22522             Электроснабжение
#
#                                          Текст инцидента  \
# 29      Здравствуйте. Почему Горнозаводское теплоэнер...
# 62      Теперь нам надо будет думать за какие деньги ...
# 63       задал вопрос про статус модерации кинотеатра...
# 77      Здравствуйте, подскажите, пожалуйста, как опр...
# 204         В какое время 9 мая пойдёт Бессмертный полк?
# ...                                                  ...
# 22352   Здравствуйте, когда будут итоги конкурса Лысь...
# 22354   Здравствуйте, скажите у меня есть земля в нал...
# 22368   А также участие в эстафете принимали студенты...
# 22506   Из Перми пишут здесь 28, 29 и 30 октября разв...
# 22522   Добрый день, данная ситуация не изменилась, н...
#
#                                   Тема
# 29                     Трудоустройство
# 62              Цены и ценообразование
# 63                 Учреждения культуры
# 77     Культурно-досуговые мероприятия
# 204                        Спецпроекты
# ...                                ...
# 22352              Учреждения культуры
# 22354             Строительство зданий
# 22368           Спортивные мероприятия
# 22506              Учреждения культуры
# 22522        Качество электроснабжения
#
# [579 rows x 4 columns]

# %%
new_data = generate_new_samples_in_dataset(bad_data)
# Out:
#   0%|          | 0/579 [00:00<?, ?it/s]

# %%
new_data1 = new_data.drop_duplicates(subset="Текст инцидента")

# %%
new_data1.to_csv("generated_train_paraphraser.csv", index=False)
