# %%
# !pip install nltk pymorphy2 umap-learn

# %%
import umap
import pandas as pd
import mlflow
from sklearn.model_selection import train_test_split, ParameterGrid
#import torch
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report, f1_score, accuracy_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from tqdm.notebook import tqdm
import pymorphy2
import pandas as pd
morph = pymorphy2.MorphAnalyzer()
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords');
stopwords = set(stopwords.words('russian'))
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
train = pd.read_csv("data/data_generated/fewshot_embed_train.csv")
test = pd.read_csv("data/data_generated/fewshot_embed_test.csv")

# %%
few_train = train[train.columns[-26:]]
train = train.drop(train.columns[-26:], axis=1)
few_test = train[train.columns[-26:]]
test = test.drop(test.columns[-26:], axis=1)
train
# Out:
#                                 Исполнитель                        Группа тем  \
# 0                               Город Пермь      Погребение и похоронное дело
# 1                               Город Пермь      Погребение и похоронное дело
# 2                               Город Пермь      Погребение и похоронное дело
# 3                               Город Пермь      Погребение и похоронное дело
# 4                               Город Пермь      Погребение и похоронное дело
# ...                                     ...                               ...
# 16847                               ИГЖН ПК                               ЖКХ
# 16848  Министерство социального развития ПК  Социальное обслуживание и защита
# 16849                               ИГЖН ПК                               ЖКХ
# 16850                               ИГЖН ПК                               ЖКХ
# 16851  Министерство социального развития ПК  Социальное обслуживание и защита
#
#                                          Текст инцидента  \
# 0      Погребения - это серьезная проблема в нашей ст...
# 1      Я также считаю, что мы должны делать все возмо...
# 2      Я думаю, что многие люди уже готовы переходить...
# 3      Я считаю, что строительство новых крематориев ...
# 4      Я думаю, что мы должны обсуждать этот вопрос о...
# ...                                                  ...
# 16847   Счёт за отопление пришёл за 1,5 месяца октябр...
# 16848   Здравствуйте, справку о том что я не получала...
# 16849   Добрый день, куда и к кому обращаться о ненад...
# 16850   Приморский 19, управляйка не чистит снег с кр...
# 16851           И как оно может заново зарегистрированно
#
#                                              Тема         0         1  \
# 0                    Погребение и похоронное дело -0.294947 -0.055111
# 1                    Погребение и похоронное дело -0.215702  0.045419
# 2                    Погребение и похоронное дело -0.074277 -0.069510
# 3                    Погребение и похоронное дело -0.215675 -0.010250
# 4                    Погребение и похоронное дело  0.091469 -0.337995
# ...                                           ...       ...       ...
# 16847      Завышение платы за коммунальные услуги  0.494950 -0.152662
# 16848                   Оказание гос. соц. помощи -0.245126 -0.062770
# 16849  Ненадлежащее содержание и эксплуатация МКД  0.096977  0.334582
# 16850               ★ Наледь и сосульки на кровле -0.198398 -0.084078
# 16851                    Дети и многодетные семьи -0.395076 -0.115507
#
#               2         3         4         5  ...      1014      1015  \
# 0     -0.917189  0.076128 -0.168686  0.458902  ...  0.023235  1.380208
# 1     -1.404945 -0.113390 -0.199697  0.628931  ...  0.064474  1.044024
# 2     -1.307976 -0.731061 -0.117746  0.112123  ... -0.352016  1.426871
# 3     -1.629285 -0.177629 -0.034335  0.769009  ...  0.172642  1.292364
# 4     -1.098347 -0.416570  0.188040  0.489746  ...  0.567005  2.010411
# ...         ...       ...       ...       ...  ...       ...       ...
# 16847 -1.038108 -0.324845  0.389979  0.587082  ...  0.546728  0.547754
# 16848 -0.160016  0.977306 -0.091960  1.371442  ...  0.213309  0.901905
# 16849  0.256389  0.675268 -0.216912  0.327004  ...  0.555713  0.927510
# 16850 -0.520404 -1.223011  0.486935  0.555129  ...  0.514814  0.568372
# 16851  0.982959  0.334874  0.263996  0.399597  ...  0.267425  0.940719
#
#            1016      1017      1018      1019      1020      1021      1022  \
# 0      0.494589  1.078209  0.454874  0.191731  0.399481 -0.026228  0.799322
# 1      0.080316  1.508044  0.344166  0.062843 -0.097315  0.063320  0.440753
# 2      0.228109  1.613876 -0.120798  0.152127  0.561417  0.173413  0.980470
# 3      0.157263  1.586579  0.690120 -0.019305  0.203964 -0.059195  0.468472
# 4     -0.007483  2.252533  1.322259  0.245822 -0.209317  0.417235  0.323693
# ...         ...       ...       ...       ...       ...       ...       ...
# 16847  0.729002  0.792730  0.791029  0.062633  0.046741  0.662049 -0.931667
# 16848  0.367159  0.690490  0.633698  0.277229 -0.180435 -0.357861 -0.234448
# 16849  0.054273 -0.680263 -0.086192 -0.246548  0.210988  0.341651 -0.130749
# 16850  0.385218  0.999179 -0.845614 -0.205630  0.443906  0.574016 -0.982858
# 16851  1.302458 -0.564014  0.095835  0.198319  0.160908 -0.493659  0.554097
#
#            1023
# 0      0.877953
# 1      0.565733
# 2      0.895009
# 3      0.829206
# 4      0.814260
# ...         ...
# 16847  0.543606
# 16848  0.931398
# 16849  0.731547
# 16850  0.722479
# 16851  0.054943
#
# [16852 rows x 1028 columns]

# %%
def lemmatize(text):
    words = text.split() # разбиваем текст на слова
    #print(words)
    res = list()
    for word in words:
        if (word not in stopwords and len(word) > 1):
            p = morph.parse(word)[0]
            res.append(p.normal_form)
    text = " ".join(res)
    return text

def text_cleaner(input_text):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', input_text)
    rem_url = re.sub(r'http\S+', '',cleantext)
    rem_url= re.sub(r'([a-z]{2}\d+[a-z]{2})',' ',rem_url)
    rem_url = re.sub(r'!+','.', rem_url)
    rem_num = re.sub('[0-9]+', '', rem_url)
    text = re.sub(r"[-—()\"#/@;:<>{}=~|€«»$\+'_–\*°“”\\√&×•ó÷≈„()‽\+.,!]+", " ", rem_num)
    text = re.sub("!",".", text)
    text = re.sub(r' +', ' ', text)
    text = re.sub(r"\[.+\]",'', text)
    emoji_pattern=re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U0001F1F2-\U0001F1F4"  # Macau flag
        u"\U0001F1E6-\U0001F1FF"  # flags
        u"\U0001F600-\U0001F64F"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U0001F1F2"
        u"\U0001F1F4"
        u"\U0001F620"
        u"\u200d"
        u"\u2640-\u2642"
        "]+", flags=re.UNICODE)

    text = emoji_pattern.sub('', text)
    text = text.lower()
    return text


def dataset_preprocessor_vectorizers(data, w_count_to_drop=3):
    data_frame = data.copy()

    indexes_to_drop = []
    # Regex для групп
    p = re.compile("\[.+\|.+\]")

    for index, row in tqdm(data_frame.iterrows()):

        # Очистка текста
        data_frame.loc[index, "Текст инцидента"] = text_cleaner(data_frame.loc[index, "Текст инцидента"])

        # Отсекаем сообщения из w_count_to_drop слов
        if len(row["Текст инцидента"].split(" ")) < w_count_to_drop and len(row["Текст инцидента"].split(".")) < w_count_to_drop:
            indexes_to_drop.append(index)

    # Лемматизация и удаление стоп слов
    for index, row in tqdm(data_frame.iterrows()):
        data_frame.loc[index, "Текст инцидента"] = lemmatize(row["Текст инцидента"])
    return data_frame
train_for_ = dataset_preprocessor_vectorizers(train)
test = dataset_preprocessor_vectorizers(test)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
import pickle
class Model_tfidf_umap:
    def __init__(self, vectorizer_name, vectorizer, max_features=None, emb_length=1024, emb_umap_size=100, vectorizer_umap_size=500):
        self.max_features = max_features
        self.vectorizer = vectorizer(max_features=self.max_features)
        self.vectorizer_name = vectorizer_name
        self.emb_length = emb_length
        self.emb_umap_size = emb_umap_size
        self.vectorizer_umap_size = vectorizer_umap_size
        
    def create_umap(self, emb_names, train, test, cols_for_umap, n_components=100):
        column_names = [emb_names+f"_{i}" for i in range(n_components)]
        ump = umap.UMAP(n_components=n_components, random_state=42)
        train_data_frame = train.copy()
        test_data_frame = test.copy()
        train_emb = ump.fit_transform(train_data_frame[cols_for_umap])
        test_emb = ump.transform(test_data_frame[cols_for_umap])
        
        return pd.DataFrame(train_emb, columns=column_names) , pd.DataFrame(test_emb, columns=column_names)
    
    def create_tfidf(self, train, test):
      tf = self.vectorizer.fit_transform(train)
      with open(f'vectorizers/{self.vectorizer_name}_vectorizer_{self.max_features}.pk', 'wb') as fin:
        pickle.dump(self.vectorizer, fin)
      vocab = self.vectorizer.vocabulary_
      train_tf, test_tf = self.create_umap("tfidf", pd.DataFrame(tf.toarray(), columns=sorted(vocab.keys())),
                             pd.DataFrame(self.vectorizer.transform(test).toarray(), columns=sorted(vocab.keys())),
                                           cols_for_umap=sorted(vocab.keys()), 
                                           n_components=self.vectorizer_umap_size)
      del tf
      return train_tf, test_tf


    def create_datasets(self, train, test):
        train_, test_ = train.copy(), test.copy()
        
        embeddings_columns = [str(i) for i in range(self.emb_length)]
        train_emb, test_emb = self.create_umap("bert_emb", 
                                          train_[embeddings_columns] ,
                                          test_[embeddings_columns], 
                                          embeddings_columns, self.emb_umap_size)
        train_ = train_[["Текст инцидента", "Группа тем", "Исполнитель", "Тема"]]
        test_ = test_[["Текст инцидента", "Группа тем", "Исполнитель", "Тема"]]
        
        train_ = pd.concat([train_, train_emb], axis=1)
        test_ = pd.concat([test_, test_emb], axis=1)
        
        train_tf_idf, test_tf_idf = self.create_tfidf(train_["Текст инцидента"].to_list(), test_["Текст инцидента"].to_list())
        
       
        
        train_ = pd.concat([train_, train_tf_idf], axis=1)
        test_ = pd.concat([test_, test_tf_idf], axis=1)
        
        del train_tf_idf
        del test_tf_idf
        #train_.to_csv(f"datasets/{self.vectorizer_name}_train_{self.max_features}.csv", index=False)
        #test_.to_csv(f"datasets/{self.vectorizer_name}_test_{self.max_features}.csv", index=False)

        return train_, test_

# %%
mtf = Model_tfidf_emb_umap("tfidf", TfidfVectorizer, max_features=15000, emb_length=1024, emb_umap_size=100, vectorizer_umap_size=500) 
train_, test_ = mtf.create_datasets(train, test)

# %%
test_ =  pd.concat([test_, few_test], axis=1)
train_ = pd.concat([train_, few_train], axis=1)
train_
# Out:
#                                          Текст инцидента  \
# 0      погребение это серьёзный проблема наш страна д...
# 1      также считать должный делать возможный поддерж...
# 2      думать многие человек готовый переходить альте...
# 3      считать строительство новый крематорий стать в...
# 4      думать должный обсуждать вопрос открыто честно...
# ...                                                  ...
# 16847  счёт отопление прийти месяц октябрь пол сентяб...
# 16848  здравствуйте справка получать пособие рождение...
# 16849  добрый день кто обращаться ненадлежащий состоя...
# 16850  приморский управляйка чистить снег крыша вчера...
# 16851                      оно заново зарегистрированный
#
#                              Группа тем                           Исполнитель  \
# 0          Погребение и похоронное дело                           Город Пермь
# 1          Погребение и похоронное дело                           Город Пермь
# 2          Погребение и похоронное дело                           Город Пермь
# 3          Погребение и похоронное дело                           Город Пермь
# 4          Погребение и похоронное дело                           Город Пермь
# ...                                 ...                                   ...
# 16847                               ЖКХ                               ИГЖН ПК
# 16848  Социальное обслуживание и защита  Министерство социального развития ПК
# 16849                               ЖКХ                               ИГЖН ПК
# 16850                               ЖКХ                               ИГЖН ПК
# 16851  Социальное обслуживание и защита  Министерство социального развития ПК
#
#                                              Тема  bert_emb_0  bert_emb_1  \
# 0                    Погребение и похоронное дело    6.083283    3.694080
# 1                    Погребение и похоронное дело    6.080633    3.698320
# 2                    Погребение и похоронное дело    6.087451    3.702007
# 3                    Погребение и похоронное дело    6.056484    3.701033
# 4                    Погребение и похоронное дело    5.329751    3.966998
# ...                                           ...         ...         ...
# 16847      Завышение платы за коммунальные услуги    6.000785    3.161868
# 16848                   Оказание гос. соц. помощи    2.046090    2.159834
# 16849  Ненадлежащее содержание и эксплуатация МКД    5.289584    3.240050
# 16850               ★ Наледь и сосульки на кровле    8.071169    4.208653
# 16851                    Дети и многодетные семьи    1.669751    4.643346
#
#        bert_emb_2  bert_emb_3  bert_emb_4  bert_emb_5  ...  \
# 0        7.694616    2.633324    5.419042    2.246113  ...
# 1        7.703132    2.633585    5.409068    2.248251  ...
# 2        7.670378    2.635363    5.430718    2.246567  ...
# 3        7.700251    2.637348    5.391547    2.254553  ...
# 4        7.647274    2.782606    4.848482    2.522091  ...
# ...           ...         ...         ...         ...  ...
# 16847   11.080984    3.330639    3.922225    2.954897  ...
# 16848   10.624887    3.404714    3.639317    3.032090  ...
# 16849   10.260251    3.042748    4.127262    2.551120  ...
# 16850   11.112345    2.834584    4.848073    2.194889  ...
# 16851    9.231742    3.192484    4.554780    2.826004  ...
#
#        nli_Строительство и архитектура  nli_Экономика и бизнес  \
# 0                             0.021046                0.004908
# 1                             0.012543                0.001811
# 2                             0.009973                0.005146
# 3                             0.014146                0.031556
# 4                             0.026353                0.027623
# ...                                ...                     ...
# 16847                         0.021880                0.028506
# 16848                         0.004896                0.018229
# 16849                         0.038565                0.002348
# 16850                         0.034284                0.013381
# 16851                         0.033518                0.021859
#
#        nli_Физическая культура и спорт  nli_Связь и телевидение  \
# 0                             0.044621                 0.049851
# 1                             0.016096                 0.046435
# 2                             0.048277                 0.050400
# 3                             0.038072                 0.049106
# 4                             0.140774                 0.039312
# ...                                ...                      ...
# 16847                         0.040916                 0.023414
# 16848                         0.063768                 0.062380
# 16849                         0.047807                 0.013241
# 16850                         0.068992                 0.009127
# 16851                         0.119247                 0.052111
#
#        nli_Газ и топливо  nli_Государственная собственность  nli_Торговля  \
# 0               0.026472                           0.016191      0.014407
# 1               0.021829                           0.015271      0.006325
# 2               0.052558                           0.007187      0.013559
# 3               0.050131                           0.011899      0.060701
# 4               0.060938                           0.011117      0.049114
# ...                  ...                                ...           ...
# 16847           0.170164                           0.013231      0.073731
# 16848           0.023841                           0.017222      0.029269
# 16849           0.008335                           0.007816      0.010814
# 16850           0.011861                           0.007010      0.023945
# 16851           0.065611                           0.013378      0.060052
#
#        nli_Памятники и объекты культурного наследия  \
# 0                                          0.049282
# 1                                          0.051986
# 2                                          0.019356
# 3                                          0.071414
# 4                                          0.017505
# ...                                             ...
# 16847                                      0.011126
# 16848                                      0.019695
# 16849                                      0.016424
# 16850                                      0.028093
# 16851                                      0.014106
#
#        nli_Погребение и похоронное дело  nli_Мобилизация
# 0                              0.131090         0.009004
# 1                              0.159060         0.002771
# 2                              0.181261         0.004151
# 3                              0.093479         0.005136
# 4                              0.031063         0.011791
# ...                                 ...              ...
# 16847                          0.003037         0.004261
# 16848                          0.004285         0.003090
# 16849                          0.010363         0.001689
# 16850                          0.005709         0.005388
# 16851                          0.019510         0.008105
#
# [16852 rows x 630 columns]

# %%
train_.to_csv("datasets/data_generated/train_with_embeddings_tfidf_umap_fewshot.csv", index=False)
test_.to_csv("datasets/data_generated/test_with_embeddings_tfidf_umap_fewshot.csv", index=False)

# %%
param_grid = {
    'iterations': [100, 250, 400, 500]
}
grid = list(ParameterGrid(param_grid))

# %%
mlflow.set_experiment('generated_sbert100_tfidf500_umap_fewshot')
# Out:
# 2023/11/25 03:29:22 INFO mlflow.tracking.fluent: Experiment with name 'generated_sbert100_tfidf500_umap_fewshot' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///workspace/mlruns/898929720009212900', creation_time=1700882962044, experiment_id='898929720009212900', last_update_time=1700882962044, lifecycle_stage='active', name='generated_sbert100_tfidf500_umap_fewshot', tags={}>

# %%
#for model_ in models:
    #model_name, vectorizer, max_features = model_
    #model = Model_tfidf(model_name, vectorizer, max_features)



for params in grid:
    try:
        with mlflow.start_run(nested=True):
            catboost_model = CatBoostClassifier(**params, verbose=0, random_seed=42)
            catboost_model.fit(train_.drop(columns=["Текст инцидента", "Группа тем", "Исполнитель", "Тема"]), train_["Группа тем"])

            predictions = catboost_model.predict(test_.drop(columns=["Текст инцидента", "Группа тем", "Исполнитель", "Тема"]))

            accuracy = accuracy_score(test_["Группа тем"], predictions)
            f1 = f1_score(test_["Группа тем"], predictions, average='weighted')
            report = classification_report(test_["Группа тем"], predictions, output_dict=True)
            report_text =  classification_report(test_["Группа тем"], predictions)


            mlflow.log_metric("report_accuracy", report['accuracy'])
            mlflow.log_metric("macro avg_precision", report['macro avg']['precision'])
            mlflow.log_metric("macro avg_recall", report['macro avg']['recall'])
            mlflow.log_metric("macro avg_f1-score", report['macro avg']['f1-score'])
            mlflow.log_metric("weighted avg_precision", report['weighted avg']['precision'])
            mlflow.log_metric("weighted avg_recall", report['weighted avg']['recall'])
            mlflow.log_metric("weighted avg_f1-score", report['weighted avg']['f1-score'])

            mlflow.log_text(report_text, "classification_report.txt")

            mlflow.set_tag("umap_emb_size", 100)
            mlflow.set_tag("umap_tfidf_size", 500)
            mlflow.set_tag("max_features", 15000)
            mlflow.set_tag("dataset_name", "sbert100_tfidf500_umap_fewshot")
            mlflow.set_tag("model_name", "catboost")
            mlflow.catboost.log_model(catboost_model, "model")
            mlflow.log_params(params)
            mlflow.log_metrics({'accuracy': accuracy, 'f1-weighted': f1})
    except Exception as e:
        error_name = type(e).name
        print(f"Caught an error: {error_name}")
        print(f"EXCEPTION: {e}")
        print(sys.exc_info()[0])
        traceback.print_exc(file=sys.stdout)
# Out:
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Cell In[71], line 13
#      11 catboost_model.fit(train_.drop(columns=["Текст инцидента", "Группа тем", "Исполнитель", "Тема"]), train_["Группа тем"])
# ---> 13 predictions = catboost_model.predict(test_.drop(columns=["Текст инцидента", "Группа тем", "Исполнитель", "Тема"]))
#      15 accuracy = accuracy_score(test_["Группа тем"], predictions)
#
# File /opt/conda/lib/python3.10/site-packages/catboost/core.py:5156, in CatBoostClassifier.predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5106 """
#    5107 Predict with data.
#    5108
#    (...)
#    5154           with log probability for every class for each object.
#    5155 """
# -> 5156 return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#
# File /opt/conda/lib/python3.10/site-packages/catboost/core.py:2508, in CatBoost._predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name, task_type)
#    2506 self._validate_prediction_type(prediction_type)
# -> 2508 predictions = self._base_predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    2509 return predictions[0] if data_is_single_object else predictions
#
# File /opt/conda/lib/python3.10/site-packages/catboost/core.py:1775, in _CatBoostBase._base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    1774 def _base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type):
# -> 1775     return self._object._base_predict(pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#
# File _catboost.pyx:4781, in _catboost._CatBoost._base_predict()
#
# File _catboost.pyx:4788, in _catboost._CatBoost._base_predict()
#
# CatBoostError: /src/catboost/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 600 should be feature with name nli_Здравоохранение/Медицина (found 998).
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[71], line 40
#      38         mlflow.log_metrics({'accuracy': accuracy, 'f1-weighted': f1})
#      39 except Exception as e:
# ---> 40     error_name = type(e).name
#      41     print(f"Caught an error: {error_name}")
#      42     print(f"EXCEPTION: {e}")
#
# AttributeError: type object 'CatBoostError' has no attribute 'name'

# %%
# Out:
#                                          Текст инцидента  \
# 0      погребение это серьёзный проблема наш страна д...
# 1      также считать должный делать возможный поддерж...
# 2      думать многие человек готовый переходить альте...
# 3      считать строительство новый крематорий стать в...
# 4      думать должный обсуждать вопрос открыто честно...
# ...                                                  ...
# 16552  счёт отопление прийти месяц октябрь пол сентяб...
# 16553  здравствуйте справка получать пособие рождение...
# 16554  добрый день обращаться ненадлежащий состояние ...
# 16555  приморский управляйка чистить снег крыша вчера...
# 16556                        оно заново зарегистрировать
#
#                              Группа тем                           Исполнитель  \
# 0          Погребение и похоронное дело                           Город Пермь
# 1          Погребение и похоронное дело                           Город Пермь
# 2          Погребение и похоронное дело                           Город Пермь
# 3          Погребение и похоронное дело                           Город Пермь
# 4          Погребение и похоронное дело                           Город Пермь
# ...                                 ...                                   ...
# 16552                               ЖКХ                               ИГЖН ПК
# 16553  Социальное обслуживание и защита  Министерство социального развития ПК
# 16554                               ЖКХ                               ИГЖН ПК
# 16555                               ЖКХ                               ИГЖН ПК
# 16556  Социальное обслуживание и защита  Министерство социального развития ПК
#
#                                              Тема  bert_emb_0  bert_emb_1  \
# 0                    Погребение и похоронное дело    6.193858    3.912866
# 1                    Погребение и похоронное дело    6.182034    3.913239
# 2                    Погребение и похоронное дело    6.193626    3.921363
# 3                    Погребение и похоронное дело    6.166926    3.913481
# 4                    Погребение и похоронное дело    5.426589    4.137989
# ...                                           ...         ...         ...
# 16552      Завышение платы за коммунальные услуги    5.802146    3.359223
# 16553                   Оказание гос. соц. помощи    1.978383    2.243957
# 16554  Ненадлежащее содержание и эксплуатация МКД    5.127955    3.364052
# 16555               ★ Наледь и сосульки на кровле    7.862041    4.475359
# 16556                    Дети и многодетные семьи    1.432578    4.952954
#
#        bert_emb_2  bert_emb_3  bert_emb_4  bert_emb_5  ...  tfidf_490  \
# 0        8.221570    2.597436    2.557736    5.019467  ...   4.492201
# 1        8.219021    2.584416    2.539699    5.037027  ...   4.491259
# 2        8.194581    2.599775    2.571837    5.004468  ...   4.493160
# 3        8.211468    2.594467    2.546340    5.036290  ...   4.492138
# 4        7.872371    2.600991    2.342771    5.481013  ...   4.489232
# ...           ...         ...         ...         ...  ...        ...
# 16552   11.347735    3.234591    1.857580    6.685138  ...   4.465665
# 16553   10.591244    3.414699    1.842726    6.676864  ...   4.459016
# 16554   10.492113    2.981782    1.837409    6.203472  ...   4.478580
# 16555   11.675790    2.809377    1.940344    5.739951  ...   4.475419
# 16556    9.354516    3.138930    2.416037    5.853949  ...   4.458853
#
#        tfidf_491  tfidf_492  tfidf_493  tfidf_494  tfidf_495  tfidf_496  \
# 0       3.140940   4.713594   4.526647   5.208543   4.716970   4.446305
# 1       3.140860   4.718349   4.532989   5.213480   4.726561   4.450813
# 2       3.140112   4.713707   4.523725   5.206819   4.712420   4.443615
# 3       3.141362   4.713727   4.526781   5.208986   4.717175   4.446662
# 4       3.136314   4.702068   4.518471   5.203340   4.704942   4.440556
# ...          ...        ...        ...        ...        ...        ...
# 16552   3.113088   4.680392   4.528454   5.215415   4.736930   4.474161
# 16553   3.087916   4.657785   4.513838   5.203963   4.716463   4.460990
# 16554   3.157574   4.708783   4.550032   5.213682   4.758401   4.464355
# 16555   3.171743   4.701551   4.547494   5.213686   4.759737   4.473089
# 16556   3.096513   4.663704   4.515500   5.209386   4.719806   4.462553
#
#        tfidf_497  tfidf_498  tfidf_499
# 0       5.084937   2.404349   3.693383
# 1       5.087780   2.409021   3.698841
# 2       5.085279   2.399018   3.691391
# 3       5.084739   2.404690   3.693920
# 4       5.078983   2.408298   3.685203
# ...          ...        ...        ...
# 16552   5.057438   2.467376   3.693809
# 16553   5.038879   2.480016   3.673120
# 16554   5.088152   2.442261   3.697817
# 16555   5.074672   2.447324   3.700868
# 16556   5.047070   2.478031   3.679089
#
# [16557 rows x 604 columns]

# %%
train = pd.read_csv("data/data_generated/train_with_embeddings_tfidf_umap_fewshot.csv")
emb_cols = [f"bert_emb_{i}" for i in range(100)]
train = train.drop([emb_cols], axis=1)
test = pd.read_csv("data/data_generated/test_with_embeddings_tfidf_umap_fewshot.csv")
test = test.drop(emb_cols, axis=1)
train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 3
#       1 train = pd.read_csv("data/data_generated/train_with_embeddings_tfidf_umap_fewshot.csv")
#       2 emb_cols = [f"bert_emb_{i}" for i in range(100)]
# ----> 3 train = train.drop([emb_cols], axis=1)
#       4 test = pd.read_csv("data/data_generated/test_with_embeddings_tfidf_umap_fewshot.csv")
#       5 test = test.drop(emb_cols, axis=1)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "[('bert_emb_0', 'bert_emb_1', 'bert_emb_2', 'bert_emb_3', 'bert_emb_4', 'bert_emb_5', 'bert_emb_6', 'bert_emb_7', 'bert_emb_8', 'bert_emb_9', 'bert_emb_10', 'bert_emb_11', 'bert_emb_12', 'bert_emb_13', 'bert_emb_14', 'bert_emb_15', 'bert_emb_16', 'bert_emb_17', 'bert_emb_18', 'bert_emb_19', 'bert_emb_20', 'bert_emb_21', 'bert_emb_22', 'bert_emb_23', 'bert_emb_24', 'bert_emb_25', 'bert_emb_26', 'bert_emb_27', 'bert_emb_28', 'bert_emb_29', 'bert_emb_30', 'bert_emb_31', 'bert_emb_32', 'bert_emb_33', 'bert_emb_34', 'bert_emb_35', 'bert_emb_36', 'bert_emb_37', 'bert_emb_38', 'bert_emb_39', 'bert_emb_40', 'bert_emb_41', 'bert_emb_42', 'bert_emb_43', 'bert_emb_44', 'bert_emb_45', 'bert_emb_46', 'bert_emb_47', 'bert_emb_48', 'bert_emb_49', 'bert_emb_50', 'bert_emb_51', 'bert_emb_52', 'bert_emb_53', 'bert_emb_54', 'bert_emb_55', 'bert_emb_56', 'bert_emb_57', 'bert_emb_58', 'bert_emb_59', 'bert_emb_60', 'bert_emb_61', 'bert_emb_62', 'bert_emb_63', 'bert_emb_64', 'bert_emb_65', 'bert_emb_66', 'bert_emb_67', 'bert_emb_68', 'bert_emb_69', 'bert_emb_70', 'bert_emb_71', 'bert_emb_72', 'bert_emb_73', 'bert_emb_74', 'bert_emb_75', 'bert_emb_76', 'bert_emb_77', 'bert_emb_78', 'bert_emb_79', 'bert_emb_80', 'bert_emb_81', 'bert_emb_82', 'bert_emb_83', 'bert_emb_84', 'bert_emb_85', 'bert_emb_86', 'bert_emb_87', 'bert_emb_88', 'bert_emb_89', 'bert_emb_90', 'bert_emb_91', 'bert_emb_92', 'bert_emb_93', 'bert_emb_94', 'bert_emb_95', 'bert_emb_96', 'bert_emb_97', 'bert_emb_98', 'bert_emb_99')] not found in axis"

# %%
columns = train.columns[4:]
new_columns = [i for i in range(26)]
dictionary = dict(zip(columns, new_columns))
train_ = train_.rename(dictionary, axis='columns')
test_ = test_.rename(dictionary, axis='columns')
# Out:
#                                          Текст инцидента  \
# 0      погребение это серьёзный проблема наш страна д...
# 1      также считать должный делать возможный поддерж...
# 2      думать многие человек готовый переходить альте...
# 3      считать строительство новый крематорий стать в...
# 4      думать должный обсуждать вопрос открыто честно...
# ...                                                  ...
# 16552  счёт отопление прийти месяц октябрь пол сентяб...
# 16553  здравствуйте справка получать пособие рождение...
# 16554  добрый день обращаться ненадлежащий состояние ...
# 16555  приморский управляйка чистить снег крыша вчера...
# 16556                        оно заново зарегистрировать
#
#                              Группа тем                           Исполнитель  \
# 0          Погребение и похоронное дело                           Город Пермь
# 1          Погребение и похоронное дело                           Город Пермь
# 2          Погребение и похоронное дело                           Город Пермь
# 3          Погребение и похоронное дело                           Город Пермь
# 4          Погребение и похоронное дело                           Город Пермь
# ...                                 ...                                   ...
# 16552                               ЖКХ                               ИГЖН ПК
# 16553  Социальное обслуживание и защита  Министерство социального развития ПК
# 16554                               ЖКХ                               ИГЖН ПК
# 16555                               ЖКХ                               ИГЖН ПК
# 16556  Социальное обслуживание и защита  Министерство социального развития ПК
#
#                                              Тема         0         1  \
# 0                    Погребение и похоронное дело  6.193858  3.912866
# 1                    Погребение и похоронное дело  6.182034  3.913239
# 2                    Погребение и похоронное дело  6.193626  3.921363
# 3                    Погребение и похоронное дело  6.166926  3.913481
# 4                    Погребение и похоронное дело  5.426589  4.137989
# ...                                           ...       ...       ...
# 16552      Завышение платы за коммунальные услуги  5.802146  3.359223
# 16553                   Оказание гос. соц. помощи  1.978383  2.243957
# 16554  Ненадлежащее содержание и эксплуатация МКД  5.127955  3.364052
# 16555               ★ Наледь и сосульки на кровле  7.862041  4.475359
# 16556                    Дети и многодетные семьи  1.432578  4.952954
#
#                2         3         4         5  ...       590       591  \
# 0       8.221570  2.597436  2.557736  5.019467  ...  4.492201  3.140940
# 1       8.219021  2.584416  2.539699  5.037027  ...  4.491259  3.140860
# 2       8.194581  2.599775  2.571837  5.004468  ...  4.493160  3.140112
# 3       8.211468  2.594467  2.546340  5.036290  ...  4.492138  3.141362
# 4       7.872371  2.600991  2.342771  5.481013  ...  4.489232  3.136314
# ...          ...       ...       ...       ...  ...       ...       ...
# 16552  11.347735  3.234591  1.857580  6.685138  ...  4.465665  3.113088
# 16553  10.591244  3.414699  1.842726  6.676864  ...  4.459016  3.087916
# 16554  10.492113  2.981782  1.837409  6.203472  ...  4.478580  3.157574
# 16555  11.675790  2.809377  1.940344  5.739951  ...  4.475419  3.171743
# 16556   9.354516  3.138930  2.416037  5.853949  ...  4.458853  3.096513
#
#             592       593       594       595       596       597       598  \
# 0      4.713594  4.526647  5.208543  4.716970  4.446305  5.084937  2.404349
# 1      4.718349  4.532989  5.213480  4.726561  4.450813  5.087780  2.409021
# 2      4.713707  4.523725  5.206819  4.712420  4.443615  5.085279  2.399018
# 3      4.713727  4.526781  5.208986  4.717175  4.446662  5.084739  2.404690
# 4      4.702068  4.518471  5.203340  4.704942  4.440556  5.078983  2.408298
# ...         ...       ...       ...       ...       ...       ...       ...
# 16552  4.680392  4.528454  5.215415  4.736930  4.474161  5.057438  2.467376
# 16553  4.657785  4.513838  5.203963  4.716463  4.460990  5.038879  2.480016
# 16554  4.708783  4.550032  5.213682  4.758401  4.464355  5.088152  2.442261
# 16555  4.701551  4.547494  5.213686  4.759737  4.473089  5.074672  2.447324
# 16556  4.663704  4.515500  5.209386  4.719806  4.462553  5.047070  2.478031
#
#             599
# 0      3.693383
# 1      3.698841
# 2      3.691391
# 3      3.693920
# 4      3.685203
# ...         ...
# 16552  3.693809
# 16553  3.673120
# 16554  3.697817
# 16555  3.700868
# 16556  3.679089
#
# [16557 rows x 604 columns]

# %%
dictionary
# Out:
# {'bert_emb_0': 0,
#  'bert_emb_1': 1,
#  'bert_emb_2': 2,
#  'bert_emb_3': 3,
#  'bert_emb_4': 4,
#  'bert_emb_5': 5,
#  'bert_emb_6': 6,
#  'bert_emb_7': 7,
#  'bert_emb_8': 8,
#  'bert_emb_9': 9,
#  'bert_emb_10': 10,
#  'bert_emb_11': 11,
#  'bert_emb_12': 12,
#  'bert_emb_13': 13,
#  'bert_emb_14': 14,
#  'bert_emb_15': 15,
#  'bert_emb_16': 16,
#  'bert_emb_17': 17,
#  'bert_emb_18': 18,
#  'bert_emb_19': 19,
#  'bert_emb_20': 20,
#  'bert_emb_21': 21,
#  'bert_emb_22': 22,
#  'bert_emb_23': 23,
#  'bert_emb_24': 24,
#  'bert_emb_25': 25,
#  'bert_emb_26': 26,
#  'bert_emb_27': 27,
#  'bert_emb_28': 28,
#  'bert_emb_29': 29,
#  'bert_emb_30': 30,
#  'bert_emb_31': 31,
#  'bert_emb_32': 32,
#  'bert_emb_33': 33,
#  'bert_emb_34': 34,
#  'bert_emb_35': 35,
#  'bert_emb_36': 36,
#  'bert_emb_37': 37,
#  'bert_emb_38': 38,
#  'bert_emb_39': 39,
#  'bert_emb_40': 40,
#  'bert_emb_41': 41,
#  'bert_emb_42': 42,
#  'bert_emb_43': 43,
#  'bert_emb_44': 44,
#  'bert_emb_45': 45,
#  'bert_emb_46': 46,
#  'bert_emb_47': 47,
#  'bert_emb_48': 48,
#  'bert_emb_49': 49,
#  'bert_emb_50': 50,
#  'bert_emb_51': 51,
#  'bert_emb_52': 52,
#  'bert_emb_53': 53,
#  'bert_emb_54': 54,
#  'bert_emb_55': 55,
#  'bert_emb_56': 56,
#  'bert_emb_57': 57,
#  'bert_emb_58': 58,
#  'bert_emb_59': 59,
#  'bert_emb_60': 60,
#  'bert_emb_61': 61,
#  'bert_emb_62': 62,
#  'bert_emb_63': 63,
#  'bert_emb_64': 64,
#  'bert_emb_65': 65,
#  'bert_emb_66': 66,
#  'bert_emb_67': 67,
#  'bert_emb_68': 68,
#  'bert_emb_69': 69,
#  'bert_emb_70': 70,
#  'bert_emb_71': 71,
#  'bert_emb_72': 72,
#  'bert_emb_73': 73,
#  'bert_emb_74': 74,
#  'bert_emb_75': 75,
#  'bert_emb_76': 76,
#  'bert_emb_77': 77,
#  'bert_emb_78': 78,
#  'bert_emb_79': 79,
#  'bert_emb_80': 80,
#  'bert_emb_81': 81,
#  'bert_emb_82': 82,
#  'bert_emb_83': 83,
#  'bert_emb_84': 84,
#  'bert_emb_85': 85,
#  'bert_emb_86': 86,
#  'bert_emb_87': 87,
#  'bert_emb_88': 88,
#  'bert_emb_89': 89,
#  'bert_emb_90': 90,
#  'bert_emb_91': 91,
#  'bert_emb_92': 92,
#  'bert_emb_93': 93,
#  'bert_emb_94': 94,
#  'bert_emb_95': 95,
#  'bert_emb_96': 96,
#  'bert_emb_97': 97,
#  'bert_emb_98': 98,
#  'bert_emb_99': 99,
#  'tfidf_0': 100,
#  'tfidf_1': 101,
#  'tfidf_2': 102,
#  'tfidf_3': 103,
#  'tfidf_4': 104,
#  'tfidf_5': 105,
#  'tfidf_6': 106,
#  'tfidf_7': 107,
#  'tfidf_8': 108,
#  'tfidf_9': 109,
#  'tfidf_10': 110,
#  'tfidf_11': 111,
#  'tfidf_12': 112,
#  'tfidf_13': 113,
#  'tfidf_14': 114,
#  'tfidf_15': 115,
#  'tfidf_16': 116,
#  'tfidf_17': 117,
#  'tfidf_18': 118,
#  'tfidf_19': 119,
#  'tfidf_20': 120,
#  'tfidf_21': 121,
#  'tfidf_22': 122,
#  'tfidf_23': 123,
#  'tfidf_24': 124,
#  'tfidf_25': 125,
#  'tfidf_26': 126,
#  'tfidf_27': 127,
#  'tfidf_28': 128,
#  'tfidf_29': 129,
#  'tfidf_30': 130,
#  'tfidf_31': 131,
#  'tfidf_32': 132,
#  'tfidf_33': 133,
#  'tfidf_34': 134,
#  'tfidf_35': 135,
#  'tfidf_36': 136,
#  'tfidf_37': 137,
#  'tfidf_38': 138,
#  'tfidf_39': 139,
#  'tfidf_40': 140,
#  'tfidf_41': 141,
#  'tfidf_42': 142,
#  'tfidf_43': 143,
#  'tfidf_44': 144,
#  'tfidf_45': 145,
#  'tfidf_46': 146,
#  'tfidf_47': 147,
#  'tfidf_48': 148,
#  'tfidf_49': 149,
#  'tfidf_50': 150,
#  'tfidf_51': 151,
#  'tfidf_52': 152,
#  'tfidf_53': 153,
#  'tfidf_54': 154,
#  'tfidf_55': 155,
#  'tfidf_56': 156,
#  'tfidf_57': 157,
#  'tfidf_58': 158,
#  'tfidf_59': 159,
#  'tfidf_60': 160,
#  'tfidf_61': 161,
#  'tfidf_62': 162,
#  'tfidf_63': 163,
#  'tfidf_64': 164,
#  'tfidf_65': 165,
#  'tfidf_66': 166,
#  'tfidf_67': 167,
#  'tfidf_68': 168,
#  'tfidf_69': 169,
#  'tfidf_70': 170,
#  'tfidf_71': 171,
#  'tfidf_72': 172,
#  'tfidf_73': 173,
#  'tfidf_74': 174,
#  'tfidf_75': 175,
#  'tfidf_76': 176,
#  'tfidf_77': 177,
#  'tfidf_78': 178,
#  'tfidf_79': 179,
#  'tfidf_80': 180,
#  'tfidf_81': 181,
#  'tfidf_82': 182,
#  'tfidf_83': 183,
#  'tfidf_84': 184,
#  'tfidf_85': 185,
#  'tfidf_86': 186,
#  'tfidf_87': 187,
#  'tfidf_88': 188,
#  'tfidf_89': 189,
#  'tfidf_90': 190,
#  'tfidf_91': 191,
#  'tfidf_92': 192,
#  'tfidf_93': 193,
#  'tfidf_94': 194,
#  'tfidf_95': 195,
#  'tfidf_96': 196,
#  'tfidf_97': 197,
#  'tfidf_98': 198,
#  'tfidf_99': 199,
#  'tfidf_100': 200,
#  'tfidf_101': 201,
#  'tfidf_102': 202,
#  'tfidf_103': 203,
#  'tfidf_104': 204,
#  'tfidf_105': 205,
#  'tfidf_106': 206,
#  'tfidf_107': 207,
#  'tfidf_108': 208,
#  'tfidf_109': 209,
#  'tfidf_110': 210,
#  'tfidf_111': 211,
#  'tfidf_112': 212,
#  'tfidf_113': 213,
#  'tfidf_114': 214,
#  'tfidf_115': 215,
#  'tfidf_116': 216,
#  'tfidf_117': 217,
#  'tfidf_118': 218,
#  'tfidf_119': 219,
#  'tfidf_120': 220,
#  'tfidf_121': 221,
#  'tfidf_122': 222,
#  'tfidf_123': 223,
#  'tfidf_124': 224,
#  'tfidf_125': 225,
#  'tfidf_126': 226,
#  'tfidf_127': 227,
#  'tfidf_128': 228,
#  'tfidf_129': 229,
#  'tfidf_130': 230,
#  'tfidf_131': 231,
#  'tfidf_132': 232,
#  'tfidf_133': 233,
#  'tfidf_134': 234,
#  'tfidf_135': 235,
#  'tfidf_136': 236,
#  'tfidf_137': 237,
#  'tfidf_138': 238,
#  'tfidf_139': 239,
#  'tfidf_140': 240,
#  'tfidf_141': 241,
#  'tfidf_142': 242,
#  'tfidf_143': 243,
#  'tfidf_144': 244,
#  'tfidf_145': 245,
#  'tfidf_146': 246,
#  'tfidf_147': 247,
#  'tfidf_148': 248,
#  'tfidf_149': 249,
#  'tfidf_150': 250,
#  'tfidf_151': 251,
#  'tfidf_152': 252,
#  'tfidf_153': 253,
#  'tfidf_154': 254,
#  'tfidf_155': 255,
#  'tfidf_156': 256,
#  'tfidf_157': 257,
#  'tfidf_158': 258,
#  'tfidf_159': 259,
#  'tfidf_160': 260,
#  'tfidf_161': 261,
#  'tfidf_162': 262,
#  'tfidf_163': 263,
#  'tfidf_164': 264,
#  'tfidf_165': 265,
#  'tfidf_166': 266,
#  'tfidf_167': 267,
#  'tfidf_168': 268,
#  'tfidf_169': 269,
#  'tfidf_170': 270,
#  'tfidf_171': 271,
#  'tfidf_172': 272,
#  'tfidf_173': 273,
#  'tfidf_174': 274,
#  'tfidf_175': 275,
#  'tfidf_176': 276,
#  'tfidf_177': 277,
#  'tfidf_178': 278,
#  'tfidf_179': 279,
#  'tfidf_180': 280,
#  'tfidf_181': 281,
#  'tfidf_182': 282,
#  'tfidf_183': 283,
#  'tfidf_184': 284,
#  'tfidf_185': 285,
#  'tfidf_186': 286,
#  'tfidf_187': 287,
#  'tfidf_188': 288,
#  'tfidf_189': 289,
#  'tfidf_190': 290,
#  'tfidf_191': 291,
#  'tfidf_192': 292,
#  'tfidf_193': 293,
#  'tfidf_194': 294,
#  'tfidf_195': 295,
#  'tfidf_196': 296,
#  'tfidf_197': 297,
#  'tfidf_198': 298,
#  'tfidf_199': 299,
#  'tfidf_200': 300,
#  'tfidf_201': 301,
#  'tfidf_202': 302,
#  'tfidf_203': 303,
#  'tfidf_204': 304,
#  'tfidf_205': 305,
#  'tfidf_206': 306,
#  'tfidf_207': 307,
#  'tfidf_208': 308,
#  'tfidf_209': 309,
#  'tfidf_210': 310,
#  'tfidf_211': 311,
#  'tfidf_212': 312,
#  'tfidf_213': 313,
#  'tfidf_214': 314,
#  'tfidf_215': 315,
#  'tfidf_216': 316,
#  'tfidf_217': 317,
#  'tfidf_218': 318,
#  'tfidf_219': 319,
#  'tfidf_220': 320,
#  'tfidf_221': 321,
#  'tfidf_222': 322,
#  'tfidf_223': 323,
#  'tfidf_224': 324,
#  'tfidf_225': 325,
#  'tfidf_226': 326,
#  'tfidf_227': 327,
#  'tfidf_228': 328,
#  'tfidf_229': 329,
#  'tfidf_230': 330,
#  'tfidf_231': 331,
#  'tfidf_232': 332,
#  'tfidf_233': 333,
#  'tfidf_234': 334,
#  'tfidf_235': 335,
#  'tfidf_236': 336,
#  'tfidf_237': 337,
#  'tfidf_238': 338,
#  'tfidf_239': 339,
#  'tfidf_240': 340,
#  'tfidf_241': 341,
#  'tfidf_242': 342,
#  'tfidf_243': 343,
#  'tfidf_244': 344,
#  'tfidf_245': 345,
#  'tfidf_246': 346,
#  'tfidf_247': 347,
#  'tfidf_248': 348,
#  'tfidf_249': 349,
#  'tfidf_250': 350,
#  'tfidf_251': 351,
#  'tfidf_252': 352,
#  'tfidf_253': 353,
#  'tfidf_254': 354,
#  'tfidf_255': 355,
#  'tfidf_256': 356,
#  'tfidf_257': 357,
#  'tfidf_258': 358,
#  'tfidf_259': 359,
#  'tfidf_260': 360,
#  'tfidf_261': 361,
#  'tfidf_262': 362,
#  'tfidf_263': 363,
#  'tfidf_264': 364,
#  'tfidf_265': 365,
#  'tfidf_266': 366,
#  'tfidf_267': 367,
#  'tfidf_268': 368,
#  'tfidf_269': 369,
#  'tfidf_270': 370,
#  'tfidf_271': 371,
#  'tfidf_272': 372,
#  'tfidf_273': 373,
#  'tfidf_274': 374,
#  'tfidf_275': 375,
#  'tfidf_276': 376,
#  'tfidf_277': 377,
#  'tfidf_278': 378,
#  'tfidf_279': 379,
#  'tfidf_280': 380,
#  'tfidf_281': 381,
#  'tfidf_282': 382,
#  'tfidf_283': 383,
#  'tfidf_284': 384,
#  'tfidf_285': 385,
#  'tfidf_286': 386,
#  'tfidf_287': 387,
#  'tfidf_288': 388,
#  'tfidf_289': 389,
#  'tfidf_290': 390,
#  'tfidf_291': 391,
#  'tfidf_292': 392,
#  'tfidf_293': 393,
#  'tfidf_294': 394,
#  'tfidf_295': 395,
#  'tfidf_296': 396,
#  'tfidf_297': 397,
#  'tfidf_298': 398,
#  'tfidf_299': 399,
#  'tfidf_300': 400,
#  'tfidf_301': 401,
#  'tfidf_302': 402,
#  'tfidf_303': 403,
#  'tfidf_304': 404,
#  'tfidf_305': 405,
#  'tfidf_306': 406,
#  'tfidf_307': 407,
#  'tfidf_308': 408,
#  'tfidf_309': 409,
#  'tfidf_310': 410,
#  'tfidf_311': 411,
#  'tfidf_312': 412,
#  'tfidf_313': 413,
#  'tfidf_314': 414,
#  'tfidf_315': 415,
#  'tfidf_316': 416,
#  'tfidf_317': 417,
#  'tfidf_318': 418,
#  'tfidf_319': 419,
#  'tfidf_320': 420,
#  'tfidf_321': 421,
#  'tfidf_322': 422,
#  'tfidf_323': 423,
#  'tfidf_324': 424,
#  'tfidf_325': 425,
#  'tfidf_326': 426,
#  'tfidf_327': 427,
#  'tfidf_328': 428,
#  'tfidf_329': 429,
#  'tfidf_330': 430,
#  'tfidf_331': 431,
#  'tfidf_332': 432,
#  'tfidf_333': 433,
#  'tfidf_334': 434,
#  'tfidf_335': 435,
#  'tfidf_336': 436,
#  'tfidf_337': 437,
#  'tfidf_338': 438,
#  'tfidf_339': 439,
#  'tfidf_340': 440,
#  'tfidf_341': 441,
#  'tfidf_342': 442,
#  'tfidf_343': 443,
#  'tfidf_344': 444,
#  'tfidf_345': 445,
#  'tfidf_346': 446,
#  'tfidf_347': 447,
#  'tfidf_348': 448,
#  'tfidf_349': 449,
#  'tfidf_350': 450,
#  'tfidf_351': 451,
#  'tfidf_352': 452,
#  'tfidf_353': 453,
#  'tfidf_354': 454,
#  'tfidf_355': 455,
#  'tfidf_356': 456,
#  'tfidf_357': 457,
#  'tfidf_358': 458,
#  'tfidf_359': 459,
#  'tfidf_360': 460,
#  'tfidf_361': 461,
#  'tfidf_362': 462,
#  'tfidf_363': 463,
#  'tfidf_364': 464,
#  'tfidf_365': 465,
#  'tfidf_366': 466,
#  'tfidf_367': 467,
#  'tfidf_368': 468,
#  'tfidf_369': 469,
#  'tfidf_370': 470,
#  'tfidf_371': 471,
#  'tfidf_372': 472,
#  'tfidf_373': 473,
#  'tfidf_374': 474,
#  'tfidf_375': 475,
#  'tfidf_376': 476,
#  'tfidf_377': 477,
#  'tfidf_378': 478,
#  'tfidf_379': 479,
#  'tfidf_380': 480,
#  'tfidf_381': 481,
#  'tfidf_382': 482,
#  'tfidf_383': 483,
#  'tfidf_384': 484,
#  'tfidf_385': 485,
#  'tfidf_386': 486,
#  'tfidf_387': 487,
#  'tfidf_388': 488,
#  'tfidf_389': 489,
#  'tfidf_390': 490,
#  'tfidf_391': 491,
#  'tfidf_392': 492,
#  'tfidf_393': 493,
#  'tfidf_394': 494,
#  'tfidf_395': 495,
#  'tfidf_396': 496,
#  'tfidf_397': 497,
#  'tfidf_398': 498,
#  'tfidf_399': 499,
#  'tfidf_400': 500,
#  'tfidf_401': 501,
#  'tfidf_402': 502,
#  'tfidf_403': 503,
#  'tfidf_404': 504,
#  'tfidf_405': 505,
#  'tfidf_406': 506,
#  'tfidf_407': 507,
#  'tfidf_408': 508,
#  'tfidf_409': 509,
#  'tfidf_410': 510,
#  'tfidf_411': 511,
#  'tfidf_412': 512,
#  'tfidf_413': 513,
#  'tfidf_414': 514,
#  'tfidf_415': 515,
#  'tfidf_416': 516,
#  'tfidf_417': 517,
#  'tfidf_418': 518,
#  'tfidf_419': 519,
#  'tfidf_420': 520,
#  'tfidf_421': 521,
#  'tfidf_422': 522,
#  'tfidf_423': 523,
#  'tfidf_424': 524,
#  'tfidf_425': 525,
#  'tfidf_426': 526,
#  'tfidf_427': 527,
#  'tfidf_428': 528,
#  'tfidf_429': 529,
#  'tfidf_430': 530,
#  'tfidf_431': 531,
#  'tfidf_432': 532,
#  'tfidf_433': 533,
#  'tfidf_434': 534,
#  'tfidf_435': 535,
#  'tfidf_436': 536,
#  'tfidf_437': 537,
#  'tfidf_438': 538,
#  'tfidf_439': 539,
#  'tfidf_440': 540,
#  'tfidf_441': 541,
#  'tfidf_442': 542,
#  'tfidf_443': 543,
#  'tfidf_444': 544,
#  'tfidf_445': 545,
#  'tfidf_446': 546,
#  'tfidf_447': 547,
#  'tfidf_448': 548,
#  'tfidf_449': 549,
#  'tfidf_450': 550,
#  'tfidf_451': 551,
#  'tfidf_452': 552,
#  'tfidf_453': 553,
#  'tfidf_454': 554,
#  'tfidf_455': 555,
#  'tfidf_456': 556,
#  'tfidf_457': 557,
#  'tfidf_458': 558,
#  'tfidf_459': 559,
#  'tfidf_460': 560,
#  'tfidf_461': 561,
#  'tfidf_462': 562,
#  'tfidf_463': 563,
#  'tfidf_464': 564,
#  'tfidf_465': 565,
#  'tfidf_466': 566,
#  'tfidf_467': 567,
#  'tfidf_468': 568,
#  'tfidf_469': 569,
#  'tfidf_470': 570,
#  'tfidf_471': 571,
#  'tfidf_472': 572,
#  'tfidf_473': 573,
#  'tfidf_474': 574,
#  'tfidf_475': 575,
#  'tfidf_476': 576,
#  'tfidf_477': 577,
#  'tfidf_478': 578,
#  'tfidf_479': 579,
#  'tfidf_480': 580,
#  'tfidf_481': 581,
#  'tfidf_482': 582,
#  'tfidf_483': 583,
#  'tfidf_484': 584,
#  'tfidf_485': 585,
#  'tfidf_486': 586,
#  'tfidf_487': 587,
#  'tfidf_488': 588,
#  'tfidf_489': 589,
#  'tfidf_490': 590,
#  'tfidf_491': 591,
#  'tfidf_492': 592,
#  'tfidf_493': 593,
#  'tfidf_494': 594,
#  'tfidf_495': 595,
#  'tfidf_496': 596,
#  'tfidf_497': 597,
#  'tfidf_498': 598,
#  'tfidf_499': 599}
